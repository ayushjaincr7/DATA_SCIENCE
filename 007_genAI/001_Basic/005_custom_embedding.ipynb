# %%
import gensim

# %%
import os
import sys

# %%
import numpy as np
import pandas as pd

# %%
import nltk

# %%
from nltk import sent_tokenize, word_tokenize

# %%
from nltk.corpus import stopwords

# %%
from gensim.utils import simple_preprocess

# %%
dir="/content/data"

# %%
dir
# Out:
# '/content/data'

# %%
import nltk
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# True

# %%
stop_words=stopwords.words('english')

# %%
def preprocess(sent):
  words=word_tokenize(sent)
  words=[word for word in words if word not in stop_words]
  sent = " ".join(words)
  return sent

# %%
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
story=[]
for filename in os.listdir(dir):
  f=open(os.path.join(dir,filename),mode='r',encoding="latin-1")
  corpus = f.read()
  sents=sent_tokenize(corpus)
  for sent in sents:
    sent = preprocess(sent)
    story.append(simple_preprocess(sent))

# %%
story
# Out:
# [['game',
#   'of',
#   'thrones',
#   'book',
#   'one',
#   'song',
#   'ice',
#   'fire',
#   'by',
#   'george',
#   'martin',
#   'prologue',
#   'we',
#   'start',
#   'back',
#   'gared',
#   'urged',
#   'woods',
#   'began',
#   'grow',
#   'dark',
#   'around'],
#  ['the', 'wildlings', 'dead'],
#  ['do', 'dead', 'frighten'],
#  ['ser', 'waymar', 'royce', 'asked', 'hint', 'smile'],
#  ['gared', 'rise', 'bait'],
#  ['he', 'old', 'man', 'past', 'fifty', 'seen', 'lordlings', 'come', 'go'],
#  ['dead', 'dead', 'said'],
#  ['we', 'business', 'dead'],
#  ['are', 'dead'],
#  ['royce', 'asked', 'softly'],
#  ['what', 'proof'],
#  ['will', 'saw', 'gared', 'said'],
#  ['if', 'says', 'dead', 'proof', 'enough'],
#  ['will', 'known', 'would', 'drag', 'quarrel', 'sooner', 'later'],
#  ['he', 'wished', 'later', 'rather', 'sooner'],
#  ['my', 'mother', 'told', 'dead', 'men', 'sing', 'songs', 'put'],
#  ['my', 'wet', 'nurse', 'said', 'thing', 'will', 'royce', 'replied'],
#  ['never', 'believe', 'anything', 'hear', 'woman', 'tit'],
#  ['there', 'things', 'learned', 'even', 'dead'],
#  ['his', 'voice', 'echoed', 'loud', 'twilit', 'forest'],
#  ['page', 'we', 'long', 'ride', 'us', 'gared', 'pointed'],
#  ['eight', 'days', 'maybe', 'nine'],
#  ['and', 'night', 'falling'],
#  ['ser', 'waymar', 'royce', 'glanced', 'sky', 'disinterest'],
#  ['it', 'every', 'day', 'time'],
#  ['are', 'unmanned', 'dark', 'gared'],
#  ['will',
#   'could',
#   'see',
#   'tightness',
#   'around',
#   'gared',
#   'mouth',
#   'barely',
#   'sup',
#   'pressed',
#   'anger',
#   'eyes',
#   'thick',
#   'black',
#   'hood',
#   'cloak'],
#  ['gared',
#   'spent',
#   'forty',
#   'years',
#   'night',
#   'watch',
#   'man',
#   'boy',
#   'accustomed',
#   'made',
#   'light'],
#  ['yet'],
#  ['under',
#   'wounded',
#   'pride',
#   'will',
#   'could',
#   'sense',
#   'something',
#   'else',
#   'older',
#   'man'],
#  ['you',
#   'could',
#   'taste',
#   'nervous',
#   'tension',
#   'came',
#   'perilous',
#   'close',
#   'fear'],
#  ['will', 'shared', 'unease'],
#  ['he', 'four', 'years', 'wall'],
#  ['the',
#   'first',
#   'time',
#   'sent',
#   'beyond',
#   'old',
#   'stories',
#   'come',
#   'rushing',
#   'back',
#   'bowels',
#   'turned',
#   'water'],
#  ['he', 'laughed', 'afterward'],
#  ['he',
#   'veteran',
#   'hundred',
#   'rangings',
#   'endless',
#   'dark',
#   'wilderness',
#   'southron',
#   'called',
#   'haunted',
#   'forest',
#   'terrors'],
#  ['until', 'tonight'],
#  ['something', 'different', 'tonight'],
#  ['there', 'edge', 'darkness', 'made', 'hackles', 'rise'],
#  ['nine',
#   'days',
#   'riding',
#   'north',
#   'northwest',
#   'north',
#   'farther',
#   'farther',
#   'wall',
#   'hard',
#   'track',
#   'band',
#   'wildling',
#   'raiders'],
#  ['each', 'day', 'worse', 'day', 'come'],
#  ['today', 'worst'],
#  ['cold',
#   'wind',
#   'blowing',
#   'north',
#   'made',
#   'trees',
#   'rustle',
#   'like',
#   'living',
#   'things'],
#  ['all',
#   'day',
#   'will',
#   'felt',
#   'though',
#   'something',
#   'watching',
#   'something',
#   'cold',
#   'implacable',
#   'loved'],
#  ['gared', 'felt'],
#  ['will',
#   'wanted',
#   'nothing',
#   'much',
#   'ride',
#   'hellbent',
#   'safety',
#   'wall',
#   'feeling',
#   'share',
#   'commander'],
#  ['especially', 'commander', 'like', 'one'],
#  ['ser',
#   'waymar',
#   'royce',
#   'youngest',
#   'son',
#   'ancient',
#   'house',
#   'many',
#   'heirs'],
#  ['he',
#   'handsome',
#   'youth',
#   'eighteen',
#   'grey',
#   'eyed',
#   'graceful',
#   'slender',
#   'knife'],
#  ['mounted',
#   'huge',
#   'black',
#   'destrier',
#   'knight',
#   'towered',
#   'will',
#   'gared',
#   'smaller',
#   'garrons'],
#  ['he',
#   'wore',
#   'black',
#   'leather',
#   'boots',
#   'black',
#   'woolen',
#   'pants',
#   'black',
#   'moleskin',
#   'gloves',
#   'fine',
#   'supple',
#   'coat',
#   'gleaming',
#   'black',
#   'ringmail',
#   'layers',
#   'black',
#   'wool',
#   'boiled',
#   'leather'],
#  ['ser',
#   'waymar',
#   'sworn',
#   'brother',
#   'night',
#   'watch',
#   'less',
#   'half',
#   'year',
#   'one',
#   'could',
#   'say',
#   'prepared',
#   'vocation'],
#  ['at', 'least', 'insofar', 'wardrobe', 'concerned'],
#  ['his',
#   'cloak',
#   'crowning',
#   'glory',
#   'sable',
#   'thick',
#   'black',
#   'soft',
#   'sin'],
#  ['bet',
#   'killed',
#   'gared',
#   'told',
#   'barracks',
#   'wine',
#   'twisted',
#   'little',
#   'heads',
#   'mighty',
#   'warrior'],
#  ['they', 'shared', 'laugh'],
#  ['it',
#   'hard',
#   'take',
#   'orders',
#   'man',
#   'laughed',
#   'cups',
#   'will',
#   'reflected',
#   'sat',
#   'shivering',
#   'atop',
#   'garron'],
#  ['gared', 'must', 'felt'],
#  ['mormont', 'said', 'track', 'gared', 'said'],
#  ['they', 're', 'dead'],
#  ['they', 'sha', 'trouble', 'us'],
#  ['there', 'hard', 'riding', 'us'],
#  ['like', 'weather'],
#  ['if',
#   'snows',
#   'could',
#   'fortnight',
#   'getting',
#   'back',
#   'snow',
#   'best',
#   'hope'],
#  ['ever', 'seen', 'ice', 'storm', 'lord'],
#  ['the', 'lordling', 'seemed', 'hear'],
#  ['he',
#   'studied',
#   'deepening',
#   'twilight',
#   'half',
#   'bored',
#   'half',
#   'distracted',
#   'page',
#   'way'],
#  ['will',
#   'ridden',
#   'knight',
#   'long',
#   'enough',
#   'understand',
#   'best',
#   'interrupt',
#   'looked',
#   'like'],
#  ['tell', 'saw', 'will'],
#  ['all', 'details'],
#  ['leave', 'nothing'],
#  ['will', 'hunter', 'joined', 'night', 'watch'],
#  ['well', 'poacher', 'truth'],
#  ['mallister',
#   'freeriders',
#   'caught',
#   'red',
#   'handed',
#   'mallisters',
#   'woods',
#   'skinning',
#   'one',
#   'mallisters',
#   'bucks',
#   'choice',
#   'putting',
#   'black',
#   'losing',
#   'hand'],
#  ['no',
#   'one',
#   'could',
#   'move',
#   'woods',
#   'silent',
#   'will',
#   'taken',
#   'black',
#   'brothers',
#   'long',
#   'discover',
#   'talent'],
#  ['the',
#   'camp',
#   'two',
#   'miles',
#   'farther',
#   'ridge',
#   'hard',
#   'beside',
#   'stream',
#   'will',
#   'said'],
#  ['got', 'close', 'dared'],
#  ['there', 'eight', 'men', 'women'],
#  ['no', 'children', 'could', 'see'],
#  ['they', 'put', 'lean', 'to', 'rock'],
#  ['the', 'snow', 'pretty', 'well', 'covered', 'could', 'still', 'make'],
#  ['no', 'fire', 'burning', 'firepit', 'still', 'plain', 'day'],
#  ['no', 'one', 'moving'],
#  ['watched', 'long', 'time'],
#  ['no', 'living', 'man', 'ever', 'lay', 'still'],
#  ['did', 'see', 'blood'],
#  ['well', 'will', 'admitted'],
#  ['did', 'see', 'weapons'],
#  ['some', 'swords', 'bows'],
#  ['one', 'man', 'axe'],
#  ['heavy', 'looking', 'double', 'bladed', 'cruel', 'piece', 'iron'],
#  ['it', 'ground', 'beside', 'right', 'hand'],
#  ['did', 'make', 'note', 'position', 'bodies'],
#  ['will', 'shrugged'],
#  ['couple', 'sitting', 'rock'],
#  ['most', 'ground'],
#  ['fallen', 'like'],
#  ['or', 'sleeping', 'royce', 'suggested'],
#  ['fallen', 'will', 'insisted'],
#  ['there', 'one', 'woman', 'ironwood', 'halfhid', 'branches'],
#  ['far', 'eyes'],
#  ['he', 'smiled', 'thinly'],
#  ['took', 'care', 'never', 'saw'],
#  ['when', 'got', 'closer', 'saw', 'moving', 'neither'],
#  ['despite', 'shivered'],
#  ['you', 'chill'],
#  ['royce', 'asked'],
#  ['some', 'will', 'muttered'],
#  ['the', 'wind', 'lord'],
#  ['the', 'young', 'knight', 'turned', 'back', 'grizzled', 'man', 'at', 'arms'],
#  ['frostfallen',
#   'leaves',
#   'whispered',
#   'past',
#   'royce',
#   'destrier',
#   'moved',
#   'restlessly'],
#  ['what', 'think', 'might', 'killed', 'men', 'gared'],
#  ['ser', 'waymar', 'asked', 'casually'],
#  ['he', 'adjusted', 'drape', 'long', 'sable', 'cloak'],
#  ['it', 'cold', 'gared', 'said', 'iron', 'certainty'],
#  ['saw', 'men', 'freeze', 'last', 'winter', 'one', 'half', 'boy'],
#  ['everyone',
#   'talks',
#   'snows',
#   'forty',
#   'foot',
#   'deep',
#   'ice',
#   'wind',
#   'comes',
#   'howling',
#   'north',
#   'real',
#   'enemy',
#   'cold'],
#  ['it',
#   'steals',
#   'quieter',
#   'will',
#   'first',
#   'shiver',
#   'teeth',
#   'chatter',
#   'stamp',
#   'feet',
#   'dream',
#   'mulled',
#   'wine',
#   'nice',
#   'hot',
#   'fires'],
#  ['it', 'burns'],
#  ['nothing', 'burns', 'like', 'cold'],
#  ['but'],
#  ['then', 'gets', 'inside', 'starts', 'fill', 'strength', 'fight'],
#  ['it', 'easier', 'sit', 'go', 'sleep'],
#  ['they', 'say', 'feel', 'pain', 'toward', 'end'],
#  ['first',
#   'go',
#   'weak',
#   'drowsy',
#   'everything',
#   'starts',
#   'fade',
#   'like',
#   'sinking',
#   'sea',
#   'warm',
#   'milk'],
#  ['peaceful', 'like'],
#  ['such', 'eloquence', 'gared', 'ser', 'waymar', 'observed'],
#  ['never', 'suspected'],
#  ['page', 've', 'cold', 'lordling'],
#  ['gared',
#   'pulled',
#   'back',
#   'hood',
#   'giving',
#   'ser',
#   'waymar',
#   'good',
#   'long',
#   'look',
#   'stumps',
#   'ears'],
#  ['two', 'ears', 'three', 'toes', 'little', 'finger', 'left', 'hand'],
#  ['got', 'light'],
#  ['we', 'found', 'brother', 'frozen', 'watch', 'smile', 'face'],
#  ['ser', 'waymar', 'shrugged'],
#  ['you', 'ought', 'dress', 'warmly', 'gared'],
#  ['gared',
#   'glared',
#   'lordling',
#   'scars',
#   'around',
#   'ear',
#   'holes',
#   'flushed',
#   'red',
#   'anger',
#   'maester',
#   'aemon',
#   'cut',
#   'ears',
#   'away'],
#  ['we', 'll', 'see', 'warm', 'dress', 'winter', 'comes'],
#  ['he', 'pulled', 'hood', 'hunched', 'garron', 'silent', 'sullen'],
#  ['if', 'gared', 'said', 'cold'],
#  [],
#  [],
#  ['will', 'began'],
#  ['have', 'drawn', 'watches', 'past', 'week', 'will'],
#  ['yes', 'lord'],
#  ['there', 'never', 'week', 'draw', 'dozen', 'bloody', 'watches'],
#  ['what', 'man', 'driving'],
#  ['and', 'find', 'wall'],
#  ['weeping', 'will', 'said', 'frowning'],
#  ['he', 'saw', 'clear', 'enough', 'lordling', 'pointed'],
#  ['they', 'could', 'froze'],
#  ['not', 'wall', 'weeping'],
#  ['it', 'cold', 'enough'],
#  ['royce', 'nodded'],
#  ['bright', 'lad'],
#  ['we',
#   've',
#   'light',
#   'frosts',
#   'past',
#   'week',
#   'quick',
#   'flurry',
#   'snow',
#   'surely',
#   'cold',
#   'fierce',
#   'enough',
#   'kill',
#   'eight',
#   'grown',
#   'men'],
#  ['men',
#   'clad',
#   'fur',
#   'leather',
#   'let',
#   'remind',
#   'shelter',
#   'near',
#   'hand',
#   'means',
#   'making',
#   'fire'],
#  ['the', 'knight', 'smile', 'cocksure'],
#  ['will', 'lead', 'us'],
#  ['would', 'see', 'dead', 'men'],
#  ['and', 'nothing', 'done'],
#  ['the', 'order', 'given', 'honor', 'bound', 'obey'],
#  ['will',
#   'went',
#   'front',
#   'shaggy',
#   'little',
#   'garron',
#   'picking',
#   'way',
#   'carefully',
#   'undergrowth'],
#  ['light',
#   'snow',
#   'fallen',
#   'night',
#   'stones',
#   'roots',
#   'hidden',
#   'sinks',
#   'lying',
#   'crust',
#   'waiting',
#   'careless',
#   'unwary'],
#  ['ser',
#   'waymar',
#   'royce',
#   'came',
#   'next',
#   'great',
#   'black',
#   'destrier',
#   'snorting',
#   'impatiently'],
#  ['the', 'warhorse', 'wrong', 'mount', 'ranging', 'try', 'tell', 'lordling'],
#  ['gared', 'brought', 'rear'],
#  ['the', 'old', 'man', 'at', 'arms', 'muttered', 'rode'],
#  ['twilight', 'deepened'],
#  ['the',
#   'cloudless',
#   'sky',
#   'turned',
#   'deep',
#   'purple',
#   'color',
#   'old',
#   'bruise',
#   'faded',
#   'black'],
#  ['the', 'stars', 'began', 'come'],
#  ['half', 'moon', 'rose'],
#  ['will', 'grateful', 'light'],
#  ['we',
#   'make',
#   'better',
#   'pace',
#   'surely',
#   'royce',
#   'said',
#   'moon',
#   'full',
#   'risen'],
#  ['not', 'horse', 'will', 'said'],
#  ['fear', 'made', 'insolent'],
#  ['perhaps', 'lord', 'would', 'care', 'take', 'lead'],
#  ['ser', 'waymar', 'royce', 'deign', 'reply'],
#  ['somewhere', 'wood', 'wolf', 'howled'],
#  ['will',
#   'pulled',
#   'garron',
#   'beneath',
#   'ancient',
#   'gnarled',
#   'ironwood',
#   'dismounted'],
#  ['page', 'why', 'stopping'],
#  ['ser', 'waymar', 'asked'],
#  ['best', 'go', 'rest', 'way', 'foot', 'lord'],
#  ['it', 'ridge'],
#  ['royce', 'paused', 'moment', 'staring', 'distance', 'face', 'reflective'],
#  ['cold', 'wind', 'whispered', 'trees'],
#  ['his',
#   'great',
#   'sable',
#   'cloak',
#   'stirred',
#   'behind',
#   'like',
#   'something',
#   'half',
#   'alive'],
#  ['there', 'something', 'wrong', 'gared', 'muttered'],
#  ['the', 'young', 'knight', 'gave', 'disdainful', 'smile'],
#  ['is'],
#  ['ca', 'feel'],
#  ['gared', 'asked'],
#  ['listen', 'darkness'],
#  ['will', 'could', 'feel'],
#  ['four', 'years', 'night', 'watch', 'never', 'afraid'],
#  ['what'],
#  ['wind'],
#  ['trees', 'rustling'],
#  ['wolf'],
#  ['which', 'sound', 'unmans', 'gared'],
#  ['when', 'gared', 'answer', 'royce', 'slid', 'gracefully', 'saddle'],
#  ['he',
#   'tied',
#   'destrier',
#   'securely',
#   'low',
#   'hanging',
#   'limb',
#   'well',
#   'away',
#   'horses',
#   'drew',
#   'longsword',
#   'sheath'],
#  ['jewels', 'glittered', 'hilt', 'moonlight', 'ran', 'shining', 'steel'],
#  ['it', 'splendid', 'weapon', 'castle', 'forged', 'new', 'made', 'look'],
#  ['will', 'doubted', 'ever', 'swung', 'anger'],
#  ['the', 'trees', 'press', 'close', 'will', 'warned'],
#  ['that', 'sword', 'tangle', 'ord'],
#  ['better', 'knife'],
#  ['if', 'need', 'instruction', 'ask', 'young', 'lord', 'said'],
#  ['gared', 'stay'],
#  ['guard', 'horses'],
#  ['gared', 'dismounted'],
#  ['we', 'need', 'fire'],
#  ['ll', 'see'],
#  ['how', 'big', 'fool', 'old', 'man'],
#  ['if', 'enemies', 'wood', 'fire', 'last', 'thing', 'want'],
#  ['there', 'enemies', 'fire', 'keep', 'away', 'gared', 'said'],
#  ['bears', 'direwolves', 'things'],
#  [],
#  [],
#  ['ser', 'waymar', 'mouth', 'became', 'hard', 'line'],
#  ['no', 'fire'],
#  ['gared',
#   'hood',
#   'shadowed',
#   'face',
#   'will',
#   'could',
#   'see',
#   'hard',
#   'glitter',
#   'eyes',
#   'stared',
#   'knight'],
#  ['for', 'moment', 'afraid', 'older', 'man', 'would', 'go', 'sword'],
#  ['it',
#   'short',
#   'ugly',
#   'thing',
#   'grip',
#   'discolored',
#   'sweat',
#   'edge',
#   'nicked',
#   'hard',
#   'use',
#   'will',
#   'would',
#   'given',
#   'iron',
#   'bob',
#   'lordling',
#   'life',
#   'gared',
#   'pulled',
#   'scabbard'],
#  ['finally', 'gared', 'looked'],
#  ['no', 'fire', 'muttered', 'low', 'breath'],
#  ['royce', 'took', 'acquiescence', 'turned', 'away'],
#  ['lead', 'said', 'will'],
#  ['will',
#   'threaded',
#   'way',
#   'thicket',
#   'started',
#   'slope',
#   'low',
#   'ridge',
#   'found',
#   'vantage',
#   'point',
#   'sentinel',
#   'tree'],
#  ['under',
#   'thin',
#   'crust',
#   'snow',
#   'ground',
#   'damp',
#   'muddy',
#   'slick',
#   'footing',
#   'rocks',
#   'hidden',
#   'roots',
#   'trip'],
#  ['will', 'made', 'sound', 'climbed'],
#  ['behind',
#   'heard',
#   'soft',
#   'metallic',
#   'slither',
#   'lordling',
#   'ringmail',
#   'rustle',
#   'leaves',
#   'muttered',
#   'curses',
#   'reaching',
#   'branches',
#   'grabbed',
#   'longsword',
#   'tugged',
#   'splendid',
#   'sable',
#   'cloak'],
#  ['the',
#   'great',
#   'sentinel',
#   'right',
#   'top',
#   'ridge',
#   'will',
#   'known',
#   'would',
#   'lowest',
#   'branches',
#   'bare',
#   'foot',
#   'ground'],
#  ['will',
#   'slid',
#   'underneath',
#   'flat',
#   'belly',
#   'snow',
#   'mud',
#   'page',
#   'looked',
#   'empty',
#   'clearing'],
#  ['his', 'heart', 'stopped', 'chest'],
#  ['for', 'moment', 'dared', 'breathe'],
#  ['moonlight',
#   'shone',
#   'clearing',
#   'ashes',
#   'firepit',
#   'snow',
#   'covered',
#   'lean',
#   'to',
#   'great',
#   'rock',
#   'little',
#   'half',
#   'frozen',
#   'stream'],
#  ['everything', 'hours', 'ago'],
#  ['they', 'gone'],
#  ['all', 'bodies', 'gone'],
#  ['gods'],
#  ['heard', 'behind'],
#  ['sword', 'slashed', 'branch', 'ser', 'waymar', 'royce', 'gained', 'ridge'],
#  ['he',
#   'stood',
#   'beside',
#   'sentinel',
#   'longsword',
#   'hand',
#   'cloak',
#   'billowing',
#   'behind',
#   'wind',
#   'came',
#   'outlined',
#   'nobly',
#   'stars',
#   'see'],
#  ['get'],
#  ['will', 'whispered', 'urgently'],
#  ['something', 'wrong'],
#  ['royce', 'move'],
#  ['he', 'looked', 'empty', 'clearing', 'laughed'],
#  ['your', 'dead', 'men', 'seem', 'moved', 'camp', 'will'],
#  ['will', 'voice', 'abandoned'],
#  ['he', 'groped', 'words', 'come'],
#  ['it', 'possible'],
#  ['his',
#   'eyes',
#   'swept',
#   'back',
#   'forth',
#   'abandoned',
#   'campsite',
#   'stopped',
#   'axe'],
#  ['huge',
#   'double',
#   'bladed',
#   'battle',
#   'axe',
#   'still',
#   'lying',
#   'seen',
#   'last',
#   'untouched'],
#  ['valuable', 'weapon'],
#  [],
#  [],
#  ['on', 'feet', 'will', 'ser', 'waymar', 'commanded'],
#  ['there', 'one'],
#  ['wo', 'hiding', 'bush'],
#  ['reluctantly', 'will', 'obeyed'],
#  ['ser', 'waymar', 'looked', 'open', 'disapproval'],
#  ['going', 'back', 'castle', 'black', 'failure', 'first', 'ranging'],
#  ['we', 'find', 'men'],
#  ['he', 'glanced', 'around'],
#  ['up', 'tree'],
#  ['be', 'quick'],
#  ['look', 'fire'],
#  ['will', 'turned', 'away', 'wordless'],
#  ['there', 'use', 'argue'],
#  ['the', 'wind', 'moving'],
#  ['it', 'cut', 'right'],
#  ['he',
#   'went',
#   'tree',
#   'vaulting',
#   'grey',
#   'green',
#   'sentinel',
#   'began',
#   'climb'],
#  ['soon', 'hands', 'sticky', 'sap', 'lost', 'among', 'needles'],
#  ['fear', 'filled', 'gut', 'like', 'meal', 'could', 'digest'],
#  ['he',
#   'whispered',
#   'prayer',
#   'nameless',
#   'gods',
#   'wood',
#   'slipped',
#   'dirk',
#   'free',
#   'sheath'],
#  ['he', 'put', 'teeth', 'keep', 'hands', 'free', 'climbing'],
#  ['the', 'taste', 'cold', 'iron', 'mouth', 'gave', 'comfort'],
#  ['down', 'lordling', 'called', 'suddenly', 'who', 'goes'],
#  ['will', 'heard', 'uncertainty', 'challenge'],
#  ['he', 'stopped', 'climbing', 'listened', 'watched'],
#  ['the',
#   'woods',
#   'gave',
#   'answer',
#   'rustle',
#   'leaves',
#   'icy',
#   'rush',
#   'stream',
#   'distant',
#   'hoot',
#   'snow',
#   'owl'],
#  ['the', 'others', 'made', 'sound'],
#  ['will', 'saw', 'movement', 'corner', 'eye'],
#  ['pale', 'shapes', 'gliding', 'wood'],
#  ['he', 'turned', 'head', 'glimpsed', 'white', 'shadow', 'darkness'],
#  ['then', 'gone'],
#  ['branches',
#   'stirred',
#   'gently',
#   'wind',
#   'scratching',
#   'one',
#   'another',
#   'wooden',
#   'fingers'],
#  ['will',
#   'opened',
#   'mouth',
#   'call',
#   'warning',
#   'words',
#   'seemed',
#   'freeze',
#   'throat'],
#  ['perhaps', 'wrong'],
#  ['perhaps', 'bird', 'reflection', 'snow', 'trick', 'moonlight'],
#  ['what', 'seen'],
#  ['will'],
#  ['ser', 'waymar', 'called'],
#  ['can', 'see', 'anything'],
#  ['he', 'turning', 'slow', 'circle', 'suddenly', 'wary', 'sword', 'hand'],
#  ['he', 'must', 'felt', 'will', 'felt'],
#  ['there', 'nothing', 'see'],
#  ['page', 'answer'],
#  ['why', 'cold'],
#  ['it', 'cold'],
#  ['shivering', 'will', 'clung', 'tightly', 'perch'],
#  ['his', 'face', 'pressed', 'hard', 'trunk', 'sentinel'],
#  ['he', 'could', 'feel', 'sweet', 'sticky', 'sap', 'cheek'],
#  ['shadow', 'emerged', 'dark', 'wood'],
#  ['it', 'stood', 'front', 'royce'],
#  ['tall', 'gaunt', 'hard', 'old', 'bones', 'flesh', 'pale', 'milk'],
#  ['its',
#   'armor',
#   'seemed',
#   'change',
#   'color',
#   'moved',
#   'white',
#   'new',
#   'fallen',
#   'snow',
#   'black',
#   'shadow',
#   'everywhere',
#   'dappled',
#   'deep',
#   'grey',
#   'green',
#   'trees'],
#  ['the',
#   'patterns',
#   'ran',
#   'like',
#   'moonlight',
#   'water',
#   'every',
#   'step',
#   'took'],
#  ['will', 'heard', 'breath', 'go', 'ser', 'waymar', 'royce', 'long', 'hiss'],
#  ['come', 'farther', 'lordling', 'warned'],
#  ['his', 'voice', 'cracked', 'like', 'boy'],
#  ['he',
#   'threw',
#   'long',
#   'sable',
#   'cloak',
#   'back',
#   'shoulders',
#   'free',
#   'arms',
#   'battle',
#   'took',
#   'sword',
#   'hands'],
#  ['the', 'wind', 'stopped'],
#  ['it', 'cold'],
#  ['the', 'other', 'slid', 'forward', 'silent', 'feet'],
#  ['in', 'hand', 'longsword', 'like', 'none', 'will', 'ever', 'seen'],
#  ['no', 'human', 'metal', 'gone', 'forging', 'blade'],
#  ['it',
#   'alive',
#   'moonlight',
#   'translucent',
#   'shard',
#   'crystal',
#   'thin',
#   'seemed',
#   'almost',
#   'vanish',
#   'seen',
#   'edge',
#   'on'],
#  ['there',
#   'faint',
#   'blue',
#   'shimmer',
#   'thing',
#   'ghost',
#   'light',
#   'played',
#   'around',
#   'edges',
#   'somehow',
#   'will',
#   'knew',
#   'sharper',
#   'razor'],
#  ['ser', 'waymar', 'met', 'bravely'],
#  ['dance'],
#  ['he', 'lifted', 'sword', 'high', 'head', 'defiant'],
#  ['his', 'hands', 'trembled', 'weight', 'perhaps', 'cold'],
#  ['yet',
#   'moment',
#   'will',
#   'thought',
#   'boy',
#   'longer',
#   'man',
#   'night',
#   'watch'],
#  ['the', 'other', 'halted'],
#  ['will',
#   'saw',
#   'eyes',
#   'blue',
#   'deeper',
#   'bluer',
#   'human',
#   'eyes',
#   'blue',
#   'burned',
#   'like',
#   'ice'],
#  ['they',
#   'fixed',
#   'longsword',
#   'trembling',
#   'high',
#   'watched',
#   'moonlight',
#   'running',
#   'cold',
#   'along',
#   'metal'],
#  ['for', 'heartbeat', 'dared', 'hope'],
#  ['they', 'emerged', 'silently', 'shadows', 'twins', 'first'],
#  ['three'],
#  [],
#  [],
#  ['four'],
#  [],
#  [],
#  ['five'],
#  [],
#  [],
#  ['ser',
#   'waymar',
#   'may',
#   'felt',
#   'cold',
#   'came',
#   'never',
#   'saw',
#   'never',
#   'heard'],
#  ['will', 'call'],
#  ['it', 'duty'],
#  ['and', 'death'],
#  ['he', 'shivered', 'hugged', 'tree', 'kept', 'silence'],
#  ['the', 'pale', 'sword', 'came', 'shivering', 'air'],
#  ['ser', 'waymar', 'met', 'steel'],
#  ['when',
#   'blades',
#   'met',
#   'ring',
#   'metal',
#   'metal',
#   'high',
#   'thin',
#   'sound',
#   'edge',
#   'hearing',
#   'like',
#   'animal',
#   'screaming',
#   'pain'],
#  ['royce', 'checked', 'second', 'blow', 'third', 'fell', 'back', 'step'],
#  ['another', 'flurry', 'blows', 'fell', 'back'],
#  ['behind',
#   'right',
#   'left',
#   'around',
#   'watchers',
#   'stood',
#   'patient',
#   'faceless',
#   'silent',
#   'shifting',
#   'patterns',
#   'delicate',
#   'armor',
#   'making',
#   'invisible',
#   'wood'],
#  ['yet', 'made', 'move', 'interfere'],
#  ['again',
#   'swords',
#   'met',
#   'will',
#   'wanted',
#   'cover',
#   'ears',
#   'strange',
#   'anguished',
#   'keening',
#   'clash'],
#  ['ser', 'waymar', 'panting', 'effort', 'breath', 'steaming', 'moonlight'],
#  ['his',
#   'blade',
#   'white',
#   'frost',
#   'other',
#   'danced',
#   'pale',
#   'blue',
#   'light'],
#  ['then', 'royce', 'parry', 'came', 'beat', 'late'],
#  ['the', 'pale', 'sword', 'bit', 'ringmail', 'beneath', 'arm'],
#  ['the', 'young', 'lord', 'cried', 'pain'],
#  ['blood', 'welled', 'rings'],
#  ['it',
#   'steamed',
#   'cold',
#   'droplets',
#   'seemed',
#   'red',
#   'fire',
#   'touched',
#   'snow'],
#  ['ser', 'page', 'waymar', 'fingers', 'brushed', 'side'],
#  ['his', 'moleskin', 'glove', 'came', 'away', 'soaked', 'red'],
#  ['the',
#   'other',
#   'said',
#   'something',
#   'language',
#   'will',
#   'know',
#   'voice',
#   'like',
#   'cracking',
#   'ice',
#   'winter',
#   'lake',
#   'words',
#   'mocking'],
#  ['ser', 'waymar', 'royce', 'found', 'fury'],
#  ['for', 'robert'],
#  ['shouted',
#   'came',
#   'snarling',
#   'lifting',
#   'frost',
#   'covered',
#   'longsword',
#   'hands',
#   'swinging',
#   'around',
#   'flat',
#   'sidearm',
#   'slash',
#   'weight',
#   'behind'],
#  ['the', 'other', 'parry', 'almost', 'lazy'],
#  ['when', 'blades', 'touched', 'steel', 'shattered'],
#  ['scream',
#   'echoed',
#   'forest',
#   'night',
#   'longsword',
#   'shivered',
#   'hundred',
#   'brittle',
#   'pieces',
#   'shards',
#   'scattering',
#   'like',
#   'rain',
#   'needles'],
#  ['royce', 'went', 'knees', 'shrieking', 'covered', 'eyes'],
#  ['blood', 'welled', 'fingers'],
#  ['the', 'watchers', 'moved', 'forward', 'together', 'signal', 'given'],
#  ['swords', 'rose', 'fell', 'deathly', 'silence'],
#  ['it', 'cold', 'butchery'],
#  ['the', 'pale', 'blades', 'sliced', 'ringmail', 'silk'],
#  ['will', 'closed', 'eyes'],
#  ['far', 'beneath', 'heard', 'voices', 'laughter', 'sharp', 'icicles'],
#  ['when',
#   'found',
#   'courage',
#   'look',
#   'long',
#   'time',
#   'passed',
#   'ridge',
#   'empty'],
#  ['he',
#   'stayed',
#   'tree',
#   'scarce',
#   'daring',
#   'breathe',
#   'moon',
#   'crept',
#   'slowly',
#   'across',
#   'black',
#   'sky'],
#  ['finally', 'muscles', 'cramping', 'fingers', 'numb', 'cold', 'climbed'],
#  ['royce', 'body', 'lay', 'facedown', 'snow', 'one', 'arm', 'outflung'],
#  ['the', 'thick', 'sable', 'cloak', 'slashed', 'dozen', 'places'],
#  ['lying', 'dead', 'like', 'saw', 'young'],
#  ['boy'],
#  ['he',
#   'found',
#   'left',
#   'sword',
#   'feet',
#   'away',
#   'end',
#   'splintered',
#   'twisted',
#   'like',
#   'tree',
#   'struck',
#   'lightning'],
#  ['will', 'knelt', 'looked', 'around', 'warily', 'snatched'],
#  ['the', 'broken', 'sword', 'would', 'proof'],
#  ['gared',
#   'would',
#   'know',
#   'make',
#   'surely',
#   'old',
#   'bear',
#   'mormont',
#   'maester',
#   'aemon'],
#  ['would', 'gared', 'still', 'waiting', 'horses'],
#  ['he', 'hurry'],
#  ['will', 'rose'],
#  ['ser', 'waymar', 'royce', 'stood'],
#  ['his', 'fine', 'clothes', 'tatter', 'face', 'ruin'],
#  ['shard', 'sword', 'transfixed', 'blind', 'white', 'pupil', 'left', 'eye'],
#  ['the', 'right', 'eye', 'open'],
#  ['the', 'pupil', 'burned', 'blue'],
#  ['it', 'saw'],
#  ['the', 'broken', 'sword', 'fell', 'nerveless', 'fingers'],
#  ['will', 'closed', 'eyes', 'pray'],
#  ['long',
#   'elegant',
#   'hands',
#   'brushed',
#   'cheek',
#   'tightened',
#   'around',
#   'throat'],
#  ['they',
#   'gloved',
#   'finest',
#   'moleskin',
#   'sticky',
#   'blood',
#   'yet',
#   'touch',
#   'icy',
#   'cold'],
#  ['bran',
#   'the',
#   'morning',
#   'dawned',
#   'clear',
#   'cold',
#   'crispness',
#   'hinted',
#   'end',
#   'summer'],
#  ['they',
#   'set',
#   'forth',
#   'daybreak',
#   'see',
#   'man',
#   'beheaded',
#   'twenty',
#   'bran',
#   'rode',
#   'among',
#   'nervous',
#   'excitement'],
#  ['this',
#   'first',
#   'time',
#   'deemed',
#   'old',
#   'enough',
#   'go',
#   'lord',
#   'father',
#   'page',
#   'brothers',
#   'see',
#   'king',
#   'justice',
#   'done'],
#  ['it', 'ninth', 'year', 'summer', 'seventh', 'bran', 'life'],
#  ['the', 'man', 'taken', 'outside', 'small', 'holdfast', 'hills'],
#  ['robb',
#   'thought',
#   'wildling',
#   'sword',
#   'sworn',
#   'mance',
#   'rayder',
#   'kingbeyond',
#   'the',
#   'wall'],
#  ['it', 'made', 'bran', 'skin', 'prickle', 'think'],
#  ['he', 'remembered', 'hearth', 'tales', 'old', 'nan', 'told'],
#  ['the', 'wildlings', 'cruel', 'men', 'said', 'slavers', 'slayers', 'thieves'],
#  ['they',
#   'consorted',
#   'giants',
#   'ghouls',
#   'stole',
#   'girl',
#   'children',
#   'dead',
#   'night',
#   'drank',
#   'blood',
#   'polished',
#   'horns'],
#  ['and',
#   'women',
#   'lay',
#   'others',
#   'long',
#   'night',
#   'sire',
#   'terrible',
#   'half',
#   'human',
#   'children'],
#  ['but',
#   'man',
#   'found',
#   'bound',
#   'hand',
#   'foot',
#   'holdfast',
#   'wall',
#   'awaiting',
#   'king',
#   'justice',
#   'old',
#   'scrawny',
#   'much',
#   'taller',
#   'robb'],
#  ['he',
#   'lost',
#   'ears',
#   'finger',
#   'frostbite',
#   'dressed',
#   'black',
#   'brother',
#   'night',
#   'watch',
#   'except',
#   'furs',
#   'ragged',
#   'greasy'],
#  ['the',
#   'breath',
#   'man',
#   'horse',
#   'mingled',
#   'steaming',
#   'cold',
#   'morning',
#   'air',
#   'lord',
#   'father',
#   'man',
#   'cut',
#   'wall',
#   'dragged'],
#  ['robb',
#   'jon',
#   'sat',
#   'tall',
#   'still',
#   'horses',
#   'bran',
#   'pony',
#   'trying',
#   'seem',
#   'older',
#   'seven',
#   'trying',
#   'pretend',
#   'seen'],
#  ['faint', 'wind', 'blew', 'holdfast', 'gate'],
#  ['over',
#   'heads',
#   'flapped',
#   'banner',
#   'starks',
#   'winterfell',
#   'grey',
#   'direwolf',
#   'racing',
#   'across',
#   'ice',
#   'white',
#   'field'],
#  ['bran',
#   'father',
#   'sat',
#   'solemnly',
#   'horse',
#   'long',
#   'brown',
#   'hair',
#   'stirring',
#   'wind'],
#  ['his',
#   'closely',
#   'trimmed',
#   'beard',
#   'shot',
#   'white',
#   'making',
#   'look',
#   'older',
#   'thirty',
#   'five',
#   'years'],
#  ['he',
#   'grim',
#   'cast',
#   'grey',
#   'eyes',
#   'day',
#   'seemed',
#   'man',
#   'would',
#   'sit',
#   'fire',
#   'evening',
#   'talk',
#   'softly',
#   'age',
#   'heroes',
#   'children',
#   'forest'],
#  ['he',
#   'taken',
#   'father',
#   'face',
#   'bran',
#   'thought',
#   'donned',
#   'face',
#   'lord',
#   'stark',
#   'winterfell'],
#  ['there',
#   'questions',
#   'asked',
#   'answers',
#   'given',
#   'chill',
#   'morning',
#   'afterward',
#   'bran',
#   'could',
#   'recall',
#   'much',
#   'said'],
#  ['finally',
#   'lord',
#   'father',
#   'gave',
#   'command',
#   'two',
#   'guardsmen',
#   'dragged',
#   'ragged',
#   'man',
#   'ironwood',
#   'stump',
#   'center',
#   'square'],
#  ['they', 'forced', 'head', 'onto', 'hard', 'black', 'wood'],
#  ['lord',
#   'eddard',
#   'stark',
#   'dismounted',
#   'ward',
#   'theon',
#   'greyjoy',
#   'brought',
#   'forth',
#   'sword'],
#  ['ice', 'sword', 'called'],
#  ['it', 'wide', 'across', 'man', 'hand', 'taller', 'even', 'robb'],
#  ['the', 'blade', 'valyrian', 'steel', 'spell', 'forged', 'dark', 'smoke'],
#  ['nothing', 'held', 'edge', 'like', 'valyrian', 'steel'],
#  ['his',
#   'father',
#   'peeled',
#   'gloves',
#   'handed',
#   'jory',
#   'cassel',
#   'captain',
#   'household',
#   'guard'],
#  ['he',
#   'took',
#   'hold',
#   'ice',
#   'hands',
#   'said',
#   'in',
#   'name',
#   'robert',
#   'house',
#   'baratheon',
#   'first',
#   'name',
#   'king',
#   'andals',
#   'rhoynar',
#   'first',
#   'men',
#   'lord',
#   'seven',
#   'kingdoms',
#   'protector',
#   'realm',
#   'word',
#   'eddard',
#   'house',
#   'stark',
#   'lord',
#   'winterfell',
#   'warden',
#   'north',
#   'sentence',
#   'die'],
#  ['he', 'lifted', 'greatsword', 'high', 'head'],
#  ['bran', 'bastard', 'brother', 'jon', 'snow', 'moved', 'closer'],
#  ['keep', 'pony', 'well', 'hand', 'whispered'],
#  ['and', 'look', 'away'],
#  ['father', 'know'],
#  ['bran', 'kept', 'pony', 'well', 'hand', 'look', 'away'],
#  ['his', 'father', 'took', 'man', 'head', 'single', 'sure', 'stroke'],
#  ['blood', 'sprayed', 'across', 'snow', 'red', 'surnmerwine'],
#  ['one', 'horses', 'reared', 'restrained', 'keep', 'bolting'],
#  ['bran', 'could', 'take', 'eyes', 'blood'],
#  ['the',
#   'snows',
#   'around',
#   'stump',
#   'drank',
#   'eagerly',
#   'reddening',
#   'watched'],
#  ['the', 'head', 'bounced', 'thick', 'root', 'rolled'],
#  ['it', 'came', 'near', 'greyjoy', 'feet'],
#  ['theon',
#   'lean',
#   'dark',
#   'page',
#   'youth',
#   'nineteen',
#   'found',
#   'everything',
#   'amusing'],
#  ['he', 'laughed', 'put', 'boot', 'head', 'kicked', 'away'],
#  ['ass', 'jon', 'muttered', 'low', 'enough', 'greyjoy', 'hear'],
#  ['he',
#   'put',
#   'hand',
#   'bran',
#   'shoulder',
#   'bran',
#   'looked',
#   'bastard',
#   'brother'],
#  ['you', 'well', 'jon', 'told', 'solemnly'],
#  ['jon', 'fourteen', 'old', 'hand', 'justice'],
#  ['it',
#   'seemed',
#   'colder',
#   'long',
#   'ride',
#   'back',
#   'winterfell',
#   'though',
#   'wind',
#   'died',
#   'sun',
#   'higher',
#   'sky'],
#  ['bran',
#   'rode',
#   'brothers',
#   'well',
#   'ahead',
#   'main',
#   'party',
#   'pony',
#   'struggling',
#   'hard',
#   'keep',
#   'horses'],
#  ['the', 'deserter', 'died', 'bravely', 'robb', 'said'],
#  ['he',
#   'big',
#   'broad',
#   'growing',
#   'every',
#   'day',
#   'mother',
#   'coloring',
#   'fair',
#   'skin',
#   'red',
#   'brown',
#   'hair',
#   'blue',
#   'eyes',
#   'tullys',
#   'riverrun'],
#  ['he', 'courage', 'least'],
#  ['no', 'jon', 'snow', 'said', 'quietly'],
#  ['it', 'courage'],
#  ['this', 'one', 'dead', 'fear'],
#  ['you', 'could', 'see', 'eyes', 'stark'],
#  ['jon', 'eyes', 'grey', 'dark', 'seemed', 'almost', 'black', 'little', 'see'],
#  ['he', 'age', 'robb', 'look', 'alike'],
#  ['jon',
#   'slender',
#   'robb',
#   'muscular',
#   'dark',
#   'robb',
#   'fair',
#   'graceful',
#   'quick',
#   'half',
#   'brother',
#   'strong',
#   'fast'],
#  ['robb', 'impressed'],
#  ['the', 'others', 'take', 'eyes', 'swore'],
#  ['he', 'died', 'well'],
#  ['race', 'bridge'],
#  ['done', 'jon', 'said', 'kicking', 'horse', 'forward'],
#  ['robb',
#   'cursed',
#   'followed',
#   'galloped',
#   'trail',
#   'robb',
#   'laughing',
#   'hooting',
#   'jon',
#   'silent',
#   'intent'],
#  ['the', 'hooves', 'horses', 'kicked', 'showers', 'snow', 'went'],
#  ['bran', 'try', 'follow'],
#  ['his', 'pony', 'could', 'keep'],
#  ['he', 'seen', 'ragged', 'man', 'eyes', 'thinking'],
#  ['after', 'sound', 'robb', 'laughter', 'receded', 'woods', 'grew', 'silent'],
#  ['so',
#   'deep',
#   'thought',
#   'never',
#   'heard',
#   'rest',
#   'party',
#   'father',
#   'moved',
#   'ride',
#   'beside'],
#  ['are', 'well', 'bran'],
#  ['asked', 'unkindly'],
#  ['yes', 'father', 'bran', 'told'],
#  ['he', 'looked'],
#  ['wrapped',
#   'furs',
#   'leathers',
#   'mounted',
#   'great',
#   'warhorse',
#   'lord',
#   'father',
#   'loomed',
#   'like',
#   'giant'],
#  ['robb', 'says', 'man', 'died', 'bravely', 'jon', 'says', 'afraid'],
#  ['what', 'think'],
#  ['father', 'asked'],
#  ['bran', 'thought'],
#  ['can', 'man', 'still', 'brave', 'afraid'],
#  ['that', 'time', 'man', 'brave', 'father', 'told'],
#  ['do', 'understand'],
#  ['he', 'wildling', 'bran', 'said'],
#  ['they', 'carry', 'women', 'sell', 'others'],
#  ['his', 'lord', 'father', 'smiled'],
#  ['old', 'nan', 'telling', 'stories'],
#  ['in', 'truth', 'man', 'oathbreaker', 'deserter', 'night', 'watch'],
#  ['no', 'man', 'dangerous'],
#  ['the',
#   'deserter',
#   'knows',
#   'life',
#   'forfeit',
#   'taken',
#   'flinch',
#   'crime',
#   'matter',
#   'vile'],
#  ['but', 'mistake'],
#  ['the', 'question', 'man', 'die', 'must'],
#  ['page', 'bran', 'answer'],
#  ['king', 'robert', 'headsman', 'said', 'uncertainly'],
#  ['he', 'father', 'admitted'],
#  ['as', 'targaryen', 'kings'],
#  ['yet', 'way', 'older', 'way'],
#  ['the',
#   'blood',
#   'first',
#   'men',
#   'still',
#   'flows',
#   'veins',
#   'starks',
#   'hold',
#   'belief',
#   'man',
#   'passes',
#   'sentence',
#   'swing',
#   'sword'],
#  ['if',
#   'would',
#   'take',
#   'man',
#   'life',
#   'owe',
#   'look',
#   'eyes',
#   'hear',
#   'final',
#   'words'],
#  ['and', 'bear', 'perhaps', 'man', 'deserve', 'die'],
#  ['one',
#   'day',
#   'bran',
#   'robb',
#   'bannerman',
#   'holding',
#   'keep',
#   'brother',
#   'king',
#   'justice',
#   'fall'],
#  ['when',
#   'day',
#   'comes',
#   'must',
#   'take',
#   'pleasure',
#   'task',
#   'neither',
#   'must',
#   'look',
#   'away'],
#  ['ruler',
#   'hides',
#   'behind',
#   'paid',
#   'executioners',
#   'soon',
#   'forgets',
#   'death'],
#  ['that', 'jon', 'reappeared', 'crest', 'hill'],
#  ['he', 'waved', 'shouted'],
#  ['father', 'bran', 'come', 'quickly', 'see', 'robb', 'found'],
#  ['then', 'gone'],
#  ['jory', 'rode', 'beside'],
#  ['trouble', 'lord'],
#  ['beyond', 'doubt', 'lord', 'father', 'said'],
#  ['come', 'let', 'us', 'see', 'mischief', 'sons', 'rooted'],
#  ['he', 'sent', 'horse', 'trot'],
#  ['jory', 'bran', 'rest', 'came'],
#  ['they',
#   'found',
#   'robb',
#   'riverbank',
#   'north',
#   'bridge',
#   'jon',
#   'still',
#   'mounted',
#   'beside'],
#  ['the', 'late', 'summer', 'snows', 'heavy', 'moonturn'],
#  ['robb',
#   'stood',
#   'knee',
#   'deep',
#   'white',
#   'hood',
#   'pulled',
#   'back',
#   'sun',
#   'shone',
#   'hair'],
#  ['he',
#   'cradling',
#   'something',
#   'arm',
#   'boys',
#   'talked',
#   'hushed',
#   'excited',
#   'voices'],
#  ['the',
#   'riders',
#   'picked',
#   'way',
#   'carefully',
#   'drifts',
#   'groping',
#   'solid',
#   'footing',
#   'hidden',
#   'uneven',
#   'ground'],
#  ['jory', 'cassel', 'theon', 'greyjoy', 'first', 'reach', 'boys'],
#  ['greyjoy', 'laughing', 'joking', 'rode'],
#  ['bran', 'heard', 'breath', 'go'],
#  ['gods'],
#  ['exclaimed', 'struggling', 'keep', 'control', 'horse', 'reached', 'sword'],
#  ['jory', 'sword', 'already'],
#  ['robb', 'get', 'away'],
#  ['called', 'horse', 'reared'],
#  ['robb', 'grinned', 'looked', 'bundle', 'arms'],
#  ['she', 'ca', 'hurt', 'said'],
#  ['she', 'dead', 'jory'],
#  ['bran', 'afire', 'curiosity'],
#  ['he',
#   'would',
#   'spurred',
#   'pony',
#   'faster',
#   'father',
#   'made',
#   'dismount',
#   'beside',
#   'bridge',
#   'approach',
#   'foot'],
#  ['bran', 'jumped', 'ran'],
#  ['by', 'jon', 'jory', 'theon', 'greyjoy', 'dismounted', 'well'],
#  ['what', 'seven', 'hells'],
#  ['greyjoy', 'saying'],
#  ['wolf', 'robb', 'told'],
#  ['freak', 'greyjoy', 'said'],
#  ['look', 'size'],
#  ['bran',
#   'heart',
#   'thumping',
#   'chest',
#   'pushed',
#   'waist',
#   'high',
#   'drift',
#   'brothers',
#   'side'],
#  ['half',
#   'buried',
#   'bloodstained',
#   'snow',
#   'huge',
#   'dark',
#   'shape',
#   'slumped',
#   'death'],
#  ['ice',
#   'formed',
#   'shaggy',
#   'grey',
#   'fur',
#   'faint',
#   'smell',
#   'corruption',
#   'clung',
#   'like',
#   'woman',
#   'perfume'],
#  ['bran',
#   'glimpsed',
#   'blind',
#   'eyes',
#   'crawling',
#   'maggots',
#   'wide',
#   'mouth',
#   'full',
#   'yellowed',
#   'teeth'],
#  ['but', 'size', 'made', 'gasp'],
#  ['it',
#   'bigger',
#   'pony',
#   'twice',
#   'size',
#   'largest',
#   'hound',
#   'father',
#   'kennel'],
#  ['page', 'it', 'freak', 'jon', 'said', 'calmly'],
#  ['that', 'direwolf'],
#  ['they', 'grow', 'larger', 'kind'],
#  ['theon',
#   'greyjoy',
#   'said',
#   'there',
#   'direwolf',
#   'sighted',
#   'south',
#   'wall',
#   'two',
#   'hundred',
#   'years'],
#  ['see', 'one', 'jon', 'replied'],
#  ['bran', 'tore', 'eyes', 'away', 'monster'],
#  ['that', 'noticed', 'bundle', 'robb', 'arms'],
#  ['he', 'gave', 'cry', 'delight', 'moved', 'closer'],
#  ['the',
#   'pup',
#   'tiny',
#   'ball',
#   'grey',
#   'black',
#   'fur',
#   'eyes',
#   'still',
#   'closed'],
#  ['it',
#   'nuzzled',
#   'blindly',
#   'robb',
#   'chest',
#   'cradled',
#   'searching',
#   'milk',
#   'among',
#   'leathers',
#   'making',
#   'sad',
#   'little',
#   'whimpery',
#   'sound'],
#  ['bran', 'reached', 'hesitantly'],
#  ['go', 'robb', 'told'],
#  ['you', 'touch'],
#  ['bran',
#   'gave',
#   'pup',
#   'quick',
#   'nervous',
#   'stroke',
#   'turned',
#   'jon',
#   'said',
#   'here',
#   'go'],
#  ['his', 'half', 'brother', 'put', 'second', 'pup', 'arms'],
#  ['there', 'five'],
#  ['bran', 'sat', 'snow', 'hugged', 'wolf', 'pup', 'face'],
#  ['its', 'fur', 'soft', 'warm', 'cheek'],
#  ['direwolves',
#   'loose',
#   'realm',
#   'many',
#   'years',
#   'muttered',
#   'hullen',
#   'master',
#   'horse'],
#  ['like'],
#  ['it', 'sign', 'jory', 'said'],
#  ['father', 'frowned'],
#  ['this', 'dead', 'animal', 'jory', 'said'],
#  ['yet', 'seemed', 'troubled'],
#  ['snow', 'crunched', 'boots', 'moved', 'around', 'body'],
#  ['do', 'know', 'killed'],
#  ['there',
#   'something',
#   'throat',
#   'robb',
#   'told',
#   'proud',
#   'found',
#   'answer',
#   'father',
#   'even',
#   'asked'],
#  ['there', 'jaw', 'his', 'father', 'knelt', 'groped', 'beast', 'head', 'hand'],
#  ['he', 'gave', 'yank', 'held', 'see'],
#  ['foot', 'shattered', 'antler', 'tines', 'snapped', 'wet', 'blood'],
#  ['sudden', 'silence', 'descended', 'party'],
#  ['the', 'men', 'looked', 'antler', 'uneasily', 'one', 'dared', 'speak'],
#  ['even', 'bran', 'could', 'sense', 'fear', 'though', 'understand'],
#  ['his', 'father', 'tossed', 'antler', 'side', 'cleansed', 'hands', 'snow'],
#  ['surprised', 'lived', 'long', 'enough', 'whelp', 'said'],
#  ['his', 'voice', 'broke', 'spell'],
#  ['maybe', 'jory', 'said'],
#  ['ve', 'heard', 'tales'],
#  [],
#  [],
#  ['maybe', 'bitch', 'already', 'dead', 'pups', 'came'],
#  ['born', 'dead', 'another', 'man', 'put'],
#  ['worse', 'luck'],
#  ['no', 'matter', 'said', 'hullen'],
#  ['they', 'dead', 'soon', 'enough'],
#  ['bran', 'gave', 'wordless', 'cry', 'dismay'],
#  ['the', 'sooner', 'better', 'theon', 'greyjoy', 'agreed'],
#  ['he', 'drew', 'sword'],
#  ['give', 'beast', 'bran'],
#  ['the', 'little', 'thing', 'squirmed', 'heard', 'understood'],
#  ['no'],
#  ['bran', 'cried', 'fiercely'],
#  ['it', 'mine'],
#  ['page', 'put', 'away', 'sword', 'greyjoy', 'robb', 'said'],
#  ['for',
#   'moment',
#   'sounded',
#   'commanding',
#   'father',
#   'like',
#   'lord',
#   'would',
#   'someday'],
#  ['we', 'keep', 'pups'],
#  ['you', 'boy', 'said', 'harwin', 'hullen', 'son'],
#  ['it', 'mercy', 'kill', 'hullen', 'said'],
#  ['bran',
#   'looked',
#   'lord',
#   'father',
#   'rescue',
#   'got',
#   'frown',
#   'furrowed',
#   'brow'],
#  ['hullen', 'speaks', 'truly', 'son'],
#  ['better', 'swift', 'death', 'hard', 'one', 'cold', 'starvation'],
#  ['no'],
#  ['he', 'could', 'feel', 'tears', 'welling', 'eyes', 'looked', 'away'],
#  ['he', 'want', 'cry', 'front', 'father'],
#  ['robb', 'resisted', 'stubbornly'],
#  ['ser', 'rodrik', 'red', 'bitch', 'whelped', 'last', 'week', 'said'],
#  ['it', 'small', 'litter', 'two', 'live', 'pups'],
#  ['she', 'll', 'milk', 'enough'],
#  ['she', 'll', 'rip', 'apart', 'try', 'nurse'],
#  ['lord', 'stark', 'jon', 'said'],
#  ['it', 'strange', 'hear', 'call', 'father', 'formal'],
#  ['bran', 'looked', 'desperate', 'hope'],
#  ['there', 'five', 'pups', 'told', 'father'],
#  ['three', 'male', 'two', 'female'],
#  ['what', 'jon'],
#  ['you', 'five', 'trueborn', 'children', 'jon', 'said'],
#  ['three', 'sons', 'two', 'daughters'],
#  ['the', 'direwolf', 'sigil', 'house'],
#  ['your', 'children', 'meant', 'pups', 'lord'],
#  ['bran',
#   'saw',
#   'father',
#   'face',
#   'change',
#   'saw',
#   'men',
#   'exchange',
#   'glances'],
#  ['he', 'loved', 'jon', 'heart', 'moment'],
#  ['even', 'seven', 'bran', 'understood', 'brother', 'done'],
#  ['the', 'count', 'come', 'right', 'jon', 'omitted'],
#  ['he',
#   'included',
#   'girls',
#   'included',
#   'even',
#   'rickon',
#   'baby',
#   'bastard',
#   'bore',
#   'surname',
#   'snow',
#   'name',
#   'custom',
#   'decreed',
#   'given',
#   'north',
#   'unlucky',
#   'enough',
#   'born',
#   'name'],
#  ['their', 'father', 'understood', 'well'],
#  ['you', 'want', 'pup', 'jon'],
#  ['asked', 'softly'],
#  ['the', 'direwolf', 'graces', 'banners', 'house', 'stark', 'jon', 'pointed'],
#  ['stark', 'father'],
#  ['their', 'lord', 'father', 'regarded', 'jon', 'thoughtfully'],
#  ['robb', 'rushed', 'silence', 'left'],
#  ['nurse', 'father', 'promised'],
#  ['soak', 'towel', 'warm', 'milk', 'give', 'suck'],
#  ['me'],
#  ['bran', 'echoed'],
#  ['the', 'lord', 'weighed', 'sons', 'long', 'carefully', 'eyes'],
#  ['easy', 'say', 'harder'],
#  ['wasting', 'servants', 'time'],
#  ['if', 'want', 'pups', 'feed'],
#  ['is', 'understood'],
#  ['bran', 'nodded', 'eagerly'],
#  ['the', 'pup', 'squirmed', 'grasp', 'licked', 'face', 'warm', 'tongue'],
#  ['you', 'must', 'train', 'well', 'father', 'said'],
#  ['you', 'must', 'train'],
#  ['the', 'kennelmaster', 'nothing', 'monsters', 'promise'],
#  ['and', 'gods', 'help', 'neglect', 'brutalize', 'train', 'badly'],
#  ['these', 'dogs', 'beg', 'treats', 'slink', 'kick'],
#  ['direwolf',
#   'rip',
#   'page',
#   'man',
#   'arm',
#   'shoulder',
#   'easily',
#   'dog',
#   'kill',
#   'rat'],
#  ['are', 'sure', 'want'],
#  ['yes', 'father', 'bran', 'said'],
#  ['yes', 'robb', 'agreed'],
#  ['the', 'pups', 'may', 'die', 'anyway', 'despite'],
#  ['they', 'wo', 'die', 'robb', 'said'],
#  ['we', 'wo', 'let', 'die'],
#  ['keep'],
#  ['jory', 'desmond', 'gather', 'pups'],
#  ['it', 'time', 'back', 'winterfell'],
#  ['it',
#   'mounted',
#   'way',
#   'bran',
#   'allowed',
#   'taste',
#   'sweet',
#   'air',
#   'victory'],
#  ['by',
#   'pup',
#   'snuggled',
#   'inside',
#   'leathers',
#   'warm',
#   'safe',
#   'long',
#   'ride',
#   'home'],
#  ['bran', 'wondering', 'name'],
#  ['halfway', 'across', 'bridge', 'jon', 'pulled', 'suddenly'],
#  ['what', 'jon'],
#  ['lord', 'father', 'asked'],
#  ['ca', 'hear'],
#  ['bran',
#   'could',
#   'hear',
#   'wind',
#   'trees',
#   'clatter',
#   'hooves',
#   'ironwood',
#   'planks',
#   'whimpering',
#   'hungry',
#   'pup',
#   'jon',
#   'listening',
#   'something',
#   'else'],
#  ['there', 'jon', 'said'],
#  ['he', 'swung', 'horse', 'around', 'galloped', 'back', 'across', 'bridge'],
#  ['they',
#   'watched',
#   'dismount',
#   'direwolf',
#   'lay',
#   'dead',
#   'snow',
#   'watched',
#   'kneel'],
#  ['moment', 'later', 'riding', 'back', 'smiling'],
#  ['he', 'must', 'crawled', 'away', 'others', 'jon', 'said'],
#  ['or', 'driven', 'away', 'father', 'said', 'looking', 'sixth', 'pup'],
#  ['his', 'fur', 'white', 'rest', 'litter', 'grey'],
#  ['his', 'eyes', 'red', 'blood', 'ragged', 'man', 'died', 'morning'],
#  ['bran',
#   'thought',
#   'curious',
#   'pup',
#   'alone',
#   'would',
#   'opened',
#   'eyes',
#   'others',
#   'still',
#   'blind'],
#  ['an', 'albino', 'theon', 'greyjoy', 'said', 'wry', 'amusement'],
#  ['this', 'one', 'die', 'even', 'faster', 'others'],
#  ['jon', 'snow', 'gave', 'father', 'ward', 'long', 'chilling', 'look'],
#  ['think', 'greyjoy', 'said'],
#  ['this', 'one', 'belongs'],
#  ['catelyn', 'catelyn', 'never', 'liked', 'godswood'],
#  ['she',
#   'born',
#   'tully',
#   'riverrun',
#   'far',
#   'south',
#   'red',
#   'fork',
#   'trident'],
#  ['the',
#   'godswood',
#   'garden',
#   'bright',
#   'airy',
#   'tall',
#   'redwoods',
#   'spread',
#   'dappled',
#   'shadows',
#   'across',
#   'tinkling',
#   'streams',
#   'birds',
#   'sang',
#   'hidden',
#   'nests',
#   'air',
#   'spicy',
#   'scent',
#   'flowers'],
#  ['page', 'the', 'gods', 'winterfell', 'kept', 'different', 'sort', 'wood'],
#  ['it',
#   'dark',
#   'primal',
#   'place',
#   'three',
#   'acres',
#   'old',
#   'forest',
#   'untouched',
#   'ten',
#   'thousand',
#   'years',
#   'gloomy',
#   'castle',
#   'rose',
#   'around'],
#  ['it', 'smelled', 'moist', 'earth', 'decay'],
#  ['no', 'redwoods', 'grew'],
#  ['this',
#   'wood',
#   'stubborn',
#   'sentinel',
#   'trees',
#   'armored',
#   'grey',
#   'green',
#   'needles',
#   'mighty',
#   'oaks',
#   'ironwoods',
#   'old',
#   'realm'],
#  ['here',
#   'thick',
#   'black',
#   'trunks',
#   'crowded',
#   'close',
#   'together',
#   'twisted',
#   'branches',
#   'wove',
#   'dense',
#   'canopy',
#   'overhead',
#   'misshappen',
#   'roots',
#   'wrestled',
#   'beneath',
#   'soil'],
#  ['this',
#   'place',
#   'deep',
#   'silence',
#   'brooding',
#   'shadows',
#   'gods',
#   'lived',
#   'names'],
#  ['but', 'knew', 'would', 'find', 'husband', 'tonight'],
#  ['whenever',
#   'took',
#   'man',
#   'life',
#   'afterward',
#   'would',
#   'seek',
#   'quiet',
#   'godswood'],
#  ['catelyn',
#   'anointed',
#   'seven',
#   'oils',
#   'named',
#   'rainbow',
#   'light',
#   'filled',
#   'sept',
#   'riverrun'],
#  ['she', 'faith', 'like', 'father', 'grandfather', 'father'],
#  ['her', 'gods', 'names', 'faces', 'familiar', 'faces', 'parents'],
#  ['worship',
#   'septon',
#   'censer',
#   'smell',
#   'incense',
#   'seven',
#   'sided',
#   'crystal',
#   'alive',
#   'light',
#   'voices',
#   'raised',
#   'song'],
#  ['the',
#   'tullys',
#   'kept',
#   'godswood',
#   'great',
#   'houses',
#   'place',
#   'walk',
#   'read',
#   'lie',
#   'sun'],
#  ['worship',
#   'sept',
#   'for',
#   'sake',
#   'ned',
#   'built',
#   'small',
#   'sept',
#   'might',
#   'sing',
#   'seven',
#   'faces',
#   'god',
#   'blood',
#   'first',
#   'men',
#   'still',
#   'flowed',
#   'veins',
#   'starks',
#   'gods',
#   'old',
#   'ones',
#   'nameless',
#   'faceless',
#   'gods',
#   'greenwood',
#   'shared',
#   'vanished',
#   'children',
#   'forest'],
#  ['at',
#   'center',
#   'grove',
#   'ancient',
#   'weirwood',
#   'brooded',
#   'small',
#   'pool',
#   'waters',
#   'black',
#   'cold'],
#  ['the', 'heart', 'tree', 'ned', 'called'],
#  ['the',
#   'weirwood',
#   'bark',
#   'white',
#   'bone',
#   'leaves',
#   'dark',
#   'red',
#   'like',
#   'thousand',
#   'bloodstained',
#   'hands'],
#  ['face',
#   'carved',
#   'trunk',
#   'great',
#   'tree',
#   'features',
#   'long',
#   'melancholy',
#   'deep',
#   'cut',
#   'eyes',
#   'red',
#   'dried',
#   'sap',
#   'strangely',
#   'watchful'],
#  ['they', 'old', 'eyes', 'older', 'winterfell'],
#  ['they',
#   'seen',
#   'brandon',
#   'builder',
#   'set',
#   'first',
#   'stone',
#   'tales',
#   'true',
#   'watched',
#   'castle',
#   'granite',
#   'walls',
#   'rise',
#   'around'],
#  ['it',
#   'said',
#   'children',
#   'forest',
#   'carved',
#   'faces',
#   'trees',
#   'dawn',
#   'centuries',
#   'coming',
#   'first',
#   'men',
#   'across',
#   'narrow',
#   'sea'],
#  ['in',
#   'south',
#   'last',
#   'weirwoods',
#   'cut',
#   'burned',
#   'thousand',
#   'years',
#   'ago',
#   'except',
#   'isle',
#   'faces',
#   'green',
#   'men',
#   'kept',
#   'silent',
#   'watch'],
#  ['up', 'different'],
#  ['here',
#   'every',
#   'castle',
#   'godswood',
#   'every',
#   'godswood',
#   'heart',
#   'tree',
#   'every',
#   'heart',
#   'tree',
#   'face'],
#  ['catelyn',
#   'found',
#   'husband',
#   'beneath',
#   'weirwood',
#   'seated',
#   'moss',
#   'covered',
#   'stone'],
#  ['the',
#   'greatsword',
#   'ice',
#   'across',
#   'lap',
#   'cleaning',
#   'blade',
#   'waters',
#   'black',
#   'night'],
#  ['thousand',
#   'years',
#   'humus',
#   'lay',
#   'thick',
#   'upon',
#   'godswood',
#   'floor',
#   'swallowing',
#   'sound',
#   'feet',
#   'red',
#   'eyes',
#   'weirwood',
#   'seemed',
#   'follow',
#   'came'],
#  ['ned', 'called', 'softly'],
#  ['he', 'lifted', 'head', 'look'],
#  ['catelyn', 'said'],
#  ['his', 'voice', 'distant', 'formal'],
#  ['where', 'children'],
#  ['he', 'would', 'always', 'ask'],
#  ['in', 'kitchen', 'arguing', 'names', 'wolf', 'pups'],
#  ['she',
#   'spread',
#   'cloak',
#   'forest',
#   'floor',
#   'sat',
#   'beside',
#   'pool',
#   'back',
#   'weirwood'],
#  ['she', 'could', 'feel', 'eyes', 'watching', 'best', 'ignore'],
#  ['arya',
#   'already',
#   'love',
#   'sansa',
#   'charmed',
#   'gracious',
#   'rickon',
#   'quite',
#   'sure'],
#  ['is', 'afraid'],
#  ['ned', 'asked'],
#  ['page', 'little', 'admitted'],
#  ['he', 'three'],
#  ['ned', 'frowned'],
#  ['he', 'must', 'learn', 'face', 'fears'],
#  ['he', 'three', 'forever'],
#  ['and', 'winter', 'coming'],
#  ['yes', 'catelyn', 'agreed'],
#  ['the', 'words', 'gave', 'chill', 'always'],
#  ['the', 'stark', 'words'],
#  ['every', 'noble', 'house', 'words'],
#  ['family',
#   'mottoes',
#   'touchstones',
#   'prayers',
#   'sorts',
#   'boasted',
#   'honor',
#   'glory',
#   'promised',
#   'loyalty',
#   'truth',
#   'swore',
#   'faith',
#   'courage'],
#  ['all', 'starks'],
#  ['winter', 'coming', 'said', 'stark', 'words'],
#  ['not', 'first', 'time', 'reflected', 'strange', 'people', 'northerners'],
#  ['the', 'man', 'died', 'well', 'll', 'give', 'ned', 'said'],
#  ['he', 'swatch', 'oiled', 'leather', 'one', 'hand'],
#  ['he',
#   'ran',
#   'lightly',
#   'greatsword',
#   'spoke',
#   'polishing',
#   'metal',
#   'dark',
#   'glow'],
#  ['glad', 'bran', 'sake'],
#  ['you', 'would', 'proud', 'bran'],
#  ['always',
#   'proud',
#   'bran',
#   'catelyn',
#   'replied',
#   'watching',
#   'sword',
#   'stroked'],
#  ['she',
#   'could',
#   'see',
#   'rippling',
#   'deep',
#   'within',
#   'steel',
#   'metal',
#   'folded',
#   'back',
#   'hundred',
#   'times',
#   'forging'],
#  ['catelyn', 'love', 'swords', 'could', 'deny', 'ice', 'beauty'],
#  ['it',
#   'forged',
#   'valyria',
#   'doom',
#   'come',
#   'old',
#   'freehold',
#   'ironsmiths',
#   'worked',
#   'metal',
#   'spells',
#   'well',
#   'hammers'],
#  ['four', 'hundred', 'years', 'old', 'sharp', 'day', 'forged'],
#  ['the',
#   'name',
#   'bore',
#   'older',
#   'still',
#   'legacy',
#   'age',
#   'heroes',
#   'starks',
#   'kings',
#   'north'],
#  ['he', 'fourth', 'year', 'ned', 'said', 'grimly'],
#  ['the', 'poor', 'man', 'half', 'mad'],
#  ['something', 'put', 'fear', 'deep', 'words', 'could', 'reach'],
#  ['he', 'sighed'],
#  ['ben', 'writes', 'strength', 'night', 'watch', 'thousand'],
#  ['it', 'desertions'],
#  ['they', 'losing', 'men', 'rangings', 'well'],
#  ['is', 'wildlings'],
#  ['asked'],
#  ['who', 'else'],
#  ['ned', 'lifted', 'ice', 'looked', 'cool', 'steel', 'length'],
#  ['and', 'grow', 'worse'],
#  ['the',
#   'day',
#   'may',
# ...
#   'bark',
#   'red',
#   'eyes',
#   'watching',
#   'listening',
#   'thinking',
#   'long',
#   'slow',
#   'thoughts'],
#  ['his', 'smile', 'gentle'],
#  ['you', 'listen', 'many', 'old', 'nan', 'stories'],
#  ['the',
#   'others',
#   'dead',
#   'children',
#   'forest',
#   'gone',
#   'eight',
#   'thousand',
#   'years'],
#  ['maester', 'luwin', 'tell', 'never', 'lived'],
#  ['no', 'living', 'man', 'ever', 'seen', 'one'],
#  ['until',
#   'morning',
#   'living',
#   'man',
#   'ever',
#   'seen',
#   'direwolf',
#   'either',
#   'catelyn',
#   'reminded'],
#  ['ought', 'know', 'better', 'argue', 'tully', 'said', 'rueful', 'smile'],
#  ['he', 'slid', 'ice', 'back', 'sheath'],
#  ['you', 'come', 'tell', 'crib', 'tales'],
#  ['know', 'little', 'like', 'place'],
#  ['what', 'lady'],
#  ['catelyn', 'took', 'husband', 'hand'],
#  ['there', 'grievous', 'news', 'today', 'lord'],
#  ['wish', 'trouble', 'cleansed'],
#  ['there', 'way', 'soften', 'blow', 'told', 'straight'],
#  ['page', 'sorry', 'love'],
#  ['jon', 'arryn', 'dead'],
#  ['his', 'eyes', 'found', 'could', 'see', 'hard', 'took', 'known', 'would'],
#  ['in',
#   'youth',
#   'ned',
#   'fostered',
#   'eyrie',
#   'childless',
#   'lord',
#   'arryn',
#   'become',
#   'second',
#   'father',
#   'fellow',
#   'ward',
#   'robert',
#   'baratheon'],
#  ['when',
#   'mad',
#   'king',
#   'aerys',
#   'targaryen',
#   'demanded',
#   'heads',
#   'lord',
#   'eyrie',
#   'raised',
#   'moon',
#   'and',
#   'falcon',
#   'banners',
#   'revolt',
#   'rather',
#   'give',
#   'pledged',
#   'protect'],
#  ['and',
#   'one',
#   'day',
#   'fifteen',
#   'years',
#   'ago',
#   'second',
#   'father',
#   'become',
#   'brother',
#   'well',
#   'ned',
#   'stood',
#   'together',
#   'sept',
#   'riverrun',
#   'wed',
#   'two',
#   'sisters',
#   'daughters',
#   'lord',
#   'hoster',
#   'tully'],
#  ['jon'],
#  [],
#  [],
#  ['said'],
#  ['is', 'news', 'certain'],
#  ['it', 'king', 'seal', 'letter', 'robert', 'hand'],
#  ['saved'],
#  ['he', 'said', 'lord', 'arryn', 'taken', 'quickly'],
#  ['even',
#   'maester',
#   'pycelle',
#   'helpless',
#   'brought',
#   'milk',
#   'poppy',
#   'jon',
#   'linger',
#   'long',
#   'pain'],
#  ['that', 'small', 'mercy', 'suppose', 'said'],
#  ['she', 'could', 'see', 'grief', 'face', 'even', 'thought', 'first'],
#  ['your', 'sister', 'said'],
#  ['and', 'jon', 'boy'],
#  ['what', 'word'],
#  ['the', 'message', 'said', 'well', 'returned', 'eyrie', 'catelyn', 'said'],
#  ['wish', 'gone', 'riverrun', 'instead'],
#  ['the', 'eyrie', 'high', 'lonely', 'ever', 'husband', 'place'],
#  ['lord', 'jon', 'memory', 'haunt', 'stone'],
#  ['know', 'sister'],
#  ['she', 'needs', 'comfort', 'family', 'friends', 'around'],
#  ['your', 'uncle', 'waits', 'vale'],
#  ['jon', 'named', 'knight', 'gate', 'heard'],
#  ['catelyn', 'nodded'],
#  ['brynden', 'boy'],
#  ['that', 'comfort', 'still'],
#  [],
#  [],
#  ['go', 'ned', 'urged'],
#  ['take', 'children'],
#  ['fill', 'halls', 'noise', 'shouts', 'laughter'],
#  ['that', 'boy', 'needs', 'children', 'lysa', 'alone', 'grief'],
#  ['would', 'could', 'catelyn', 'said'],
#  ['the', 'letter', 'tidings'],
#  ['the', 'king', 'riding', 'winterfell', 'seek'],
#  ['it',
#   'took',
#   'ned',
#   'moment',
#   'comprehend',
#   'words',
#   'understanding',
#   'came',
#   'darkness',
#   'left',
#   'eyes'],
#  ['robert', 'coming'],
#  ['when', 'nodded', 'smile', 'broke', 'across', 'face'],
#  ['catelyn', 'wished', 'could', 'share', 'joy'],
#  ['but',
#   'heard',
#   'talk',
#   'yards',
#   'direwolf',
#   'dead',
#   'snow',
#   'broken',
#   'antler',
#   'throat'],
#  ['dread',
#   'coiled',
#   'within',
#   'like',
#   'snake',
#   'forced',
#   'smile',
#   'man',
#   'loved',
#   'man',
#   'put',
#   'faith',
#   'signs'],
#  ['knew', 'would', 'please', 'said'],
#  ['we', 'send', 'word', 'brother', 'wall'],
#  ['yes', 'course', 'agreed'],
#  ['ben', 'want'],
#  ['shall', 'tell', 'maester', 'luwin', 'send', 'swiftest', 'bird'],
#  ['ned', 'rose', 'pulled', 'feet'],
#  ['damnation', 'many', 'years'],
#  ['and', 'gives', 'us', 'notice'],
#  ['how', 'many', 'party', 'message', 'say'],
#  ['think',
#   'hundred',
#   'knights',
#   'least',
#   'retainers',
#   'half',
#   'many',
#   'freeriders'],
#  ['page', 'cersei', 'children', 'travel'],
#  ['robert', 'keep', 'easy', 'pace', 'sakes', 'said'],
#  ['it', 'well'],
#  ['that', 'give', 'us', 'time', 'prepare'],
#  ['the', 'queen', 'brothers', 'also', 'party', 'told'],
#  ['ned', 'grimaced'],
#  ['there', 'small', 'love', 'queen', 'family', 'catelyn', 'knew'],
#  ['the',
#   'lannisters',
#   'casterly',
#   'rock',
#   'come',
#   'late',
#   'robert',
#   'cause',
#   'victory',
#   'certain',
#   'never',
#   'forgiven'],
#  ['well', 'price', 'robert', 'company', 'infestation', 'lannisters'],
#  ['it', 'sounds', 'though', 'robert', 'bringing', 'half', 'court'],
#  ['where', 'king', 'goes', 'realm', 'follows', 'said'],
#  ['it', 'good', 'see', 'children'],
#  ['the',
#   'youngest',
#   'still',
#   'sucking',
#   'lannister',
#   'woman',
#   'teat',
#   'last',
#   'time',
#   'saw'],
#  ['he', 'must', 'five'],
#  ['prince', 'tornmen', 'seven', 'told'],
#  ['the', 'age', 'bran'],
#  ['please', 'ned', 'guard', 'tongue'],
#  ['the',
#   'lannister',
#   'woman',
#   'queen',
#   'pride',
#   'said',
#   'grow',
#   'every',
#   'passing',
#   'year'],
#  ['ned', 'squeezed', 'hand'],
#  ['there', 'must', 'feast', 'course', 'singers', 'robert', 'want', 'hunt'],
#  ['shall',
#   'send',
#   'jory',
#   'south',
#   'honor',
#   'guard',
#   'meet',
#   'kingsroad',
#   'escort',
#   'back'],
#  ['gods', 'going', 'feed'],
#  ['on', 'way', 'already', 'said'],
#  ['damn', 'man'],
#  ['damn', 'royal', 'hide'],
#  ['daenerys', 'her', 'brother', 'held', 'gown', 'inspection'],
#  ['this', 'beauty'],
#  ['touch'],
#  ['go'],
#  ['caress', 'fabric'],
#  ['dany', 'touched'],
#  ['the', 'cloth', 'smooth', 'seemed', 'run', 'fingers', 'like', 'water'],
#  ['she', 'could', 'remember', 'ever', 'wearing', 'anything', 'soft'],
#  ['it', 'frightened'],
#  ['she', 'pulled', 'hand', 'away'],
#  ['is', 'really', 'mine'],
#  ['gift', 'magister', 'illyrio', 'viserys', 'said', 'smiling'],
#  ['her', 'brother', 'high', 'mood', 'tonight'],
#  ['the', 'color', 'bring', 'violet', 'eyes'],
#  ['and', 'shall', 'gold', 'well', 'jewels', 'sorts'],
#  ['illyrio', 'promised'],
#  ['tonight', 'must', 'look', 'like', 'princess'],
#  ['princess', 'dany', 'thought'],
#  ['she', 'forgotten', 'like'],
#  ['perhaps', 'never', 'really', 'known'],
#  ['why', 'give', 'us', 'much'],
#  ['asked'],
#  ['what', 'want', 'us'],
#  ['for',
#   'nigh',
#   'half',
#   'year',
#   'lived',
#   'magister',
#   'house',
#   'eating',
#   'food',
#   'pampered',
#   'servants'],
#  ['dany',
#   'thirteen',
#   'old',
#   'enough',
#   'know',
#   'gifts',
#   'seldom',
#   'come',
#   'without',
#   'price',
#   'free',
#   'city',
#   'pentos'],
#  ['illyrio', 'fool', 'viserys', 'said'],
#  ['he',
#   'gaunt',
#   'young',
#   'man',
#   'nervous',
#   'hands',
#   'feverish',
#   'look',
#   'pale',
#   'lilac',
#   'eyes'],
#  ['the', 'magister', 'knows', 'forget', 'friends', 'come', 'throne'],
#  ['dany', 'said', 'nothing'],
#  ['magister',
#   'illyrio',
#   'dealer',
#   'spices',
#   'gemstones',
#   'dragonbone',
#   'less',
#   'savory',
#   'things'],
#  ['he',
#   'friends',
#   'nine',
#   'free',
#   'cities',
#   'said',
#   'even',
#   'beyond',
#   'vaes',
#   'dothrak',
#   'fabled',
#   'lands',
#   'beside',
#   'jade',
#   'sea'],
#  ['it',
#   'also',
#   'said',
#   'never',
#   'friend',
#   'would',
#   'page',
#   'cheerfully',
#   'sell',
#   'right',
#   'price'],
#  ['dany',
#   'listened',
#   'talk',
#   'streets',
#   'heard',
#   'things',
#   'knew',
#   'better',
#   'question',
#   'brother',
#   'wove',
#   'webs',
#   'dream'],
#  ['his', 'anger', 'terrible', 'thing', 'roused'],
#  ['viserys', 'called', 'waking', 'dragon'],
#  ['her', 'brother', 'hung', 'gown', 'beside', 'door'],
#  ['illyrio', 'send', 'slaves', 'bathe'],
#  ['be', 'sure', 'wash', 'stink', 'stables'],
#  ['khal',
#   'drogo',
#   'thousand',
#   'horses',
#   'tonight',
#   'looks',
#   'different',
#   'sort',
#   'mount'],
#  ['he', 'studied', 'critically'],
#  ['you', 'still', 'slouch'],
#  ['straighten', 'he', 'pushed', 'back', 'shoulders', 'hands'],
#  ['let', 'see', 'woman', 'shape'],
#  ['his',
#   'fingers',
#   'brushed',
#   'lightly',
#   'budding',
#   'breasts',
#   'tightened',
#   'nipple'],
#  ['you', 'fail', 'tonight'],
#  ['if', 'go', 'hard'],
#  ['you', 'want', 'wake', 'dragon'],
#  ['his',
#   'fingers',
#   'twisted',
#   'pinch',
#   'cruelly',
#   'hard',
#   'rough',
#   'fabric',
#   'tunic'],
#  ['do'],
#  ['repeated'],
#  ['no', 'dany', 'said', 'meekly'],
#  ['her', 'brother', 'smiled'],
#  ['good'],
#  ['he', 'touched', 'hair', 'almost', 'affection'],
#  ['when',
#   'write',
#   'history',
#   'reign',
#   'sweet',
#   'sister',
#   'say',
#   'began',
#   'tonight'],
#  ['when',
#   'gone',
#   'dany',
#   'went',
#   'window',
#   'looked',
#   'wistfully',
#   'waters',
#   'bay'],
#  ['the',
#   'square',
#   'brick',
#   'towers',
#   'pentos',
#   'black',
#   'silhouettes',
#   'outlined',
#   'setting',
#   'sun'],
#  ['dany',
#   'could',
#   'hear',
#   'singing',
#   'red',
#   'priests',
#   'lit',
#   'night',
#   'fires',
#   'shouts',
#   'ragged',
#   'children',
#   'playing',
#   'games',
#   'beyond',
#   'walls',
#   'estate'],
#  ['for',
#   'moment',
#   'wished',
#   'could',
#   'barefoot',
#   'breathless',
#   'dressed',
#   'tatters',
#   'past',
#   'future',
#   'feast',
#   'attend',
#   'khal',
#   'drogo',
#   'manse'],
#  ['somewhere',
#   'beyond',
#   'sunset',
#   'across',
#   'narrow',
#   'sea',
#   'lay',
#   'land',
#   'green',
#   'hills',
#   'flowered',
#   'plains',
#   'great',
#   'rushing',
#   'rivers',
#   'towers',
#   'dark',
#   'stone',
#   'rose',
#   'amidst',
#   'magnificent',
#   'blue',
#   'grey',
#   'mountains',
#   'armored',
#   'knights',
#   'rode',
#   'battle',
#   'beneath',
#   'banners',
#   'lords'],
#  ['the', 'dothraki', 'called', 'land', 'rhaesh', 'andahli', 'land', 'andals'],
#  ['in', 'free', 'cities', 'talked', 'westeros', 'sunset', 'kingdoms'],
#  ['her', 'brother', 'simpler', 'name'],
#  ['our', 'land', 'called'],
#  ['the', 'words', 'like', 'prayer'],
#  ['if', 'said', 'enough', 'gods', 'sure', 'hear'],
#  ['ours', 'blood', 'right', 'taken', 'us', 'treachery', 'still', 'forever'],
#  ['you', 'steal', 'dragon', 'oh'],
#  ['the', 'dragon', 'remembers'],
#  ['and', 'perhaps', 'dragon', 'remember', 'dany', 'could'],
#  ['she',
#   'never',
#   'seen',
#   'land',
#   'brother',
#   'said',
#   'realm',
#   'beyond',
#   'narrow',
#   'sea'],
#  ['these',
#   'places',
#   'talked',
#   'casterly',
#   'rock',
#   'eyrie',
#   'highgarden',
#   'vale',
#   'arryn',
#   'dorne',
#   'isle',
#   'faces',
#   'words'],
#  ['viserys',
#   'boy',
#   'eight',
#   'fled',
#   'king',
#   'landing',
#   'escape',
#   'advancing',
#   'armies',
#   'usurper',
#   'daenerys',
#   'quickening',
#   'mother',
#   'womb'],
#  ['yet',
#   'sometimes',
#   'dany',
#   'would',
#   'picture',
#   'way',
#   'often',
#   'brother',
#   'told',
#   'stories'],
#  ['the',
#   'midnight',
#   'flight',
#   'dragonstone',
#   'moonlight',
#   'shimmering',
#   'ship',
#   'black',
#   'sails'],
#  ['her',
#   'brother',
#   'rhaegar',
#   'battling',
#   'usurper',
#   'bloody',
#   'waters',
#   'trident',
#   'dying',
#   'woman',
#   'loved'],
#  ['the',
#   'sack',
#   'king',
#   'landing',
#   'ones',
#   'viserys',
#   'called',
#   'usurper',
#   'dogs',
#   'lords',
#   'lannister',
#   'stark'],
#  ['princess',
#   'elia',
#   'dorne',
#   'pleading',
#   'mercy',
#   'rhaegar',
#   'heir',
#   'ripped',
#   'breast',
#   'murdered',
#   'eyes'],
#  ['the',
#   'polished',
#   'skulls',
#   'last',
#   'dragons',
#   'staring',
#   'sightlessly',
#   'walls',
#   'throne',
#   'room',
#   'kingslayer',
#   'opened',
#   'father',
#   'throat',
#   'golden',
#   'sword'],
#  ['she',
#   'born',
#   'dragonstone',
#   'nine',
#   'moons',
#   'flight',
#   'raging',
#   'summer',
#   'storm',
#   'threatened',
#   'rip',
#   'island',
#   'fastness',
#   'apart'],
#  ['they', 'said', 'storm', 'terrible'],
#  ['the',
#   'targaryen',
#   'fleet',
#   'smashed',
#   'lay',
#   'anchor',
#   'huge',
#   'stone',
#   'blocks',
#   'ripped',
#   'parapets',
#   'sent',
#   'hurtling',
#   'wild',
#   'waters',
#   'narrow',
#   'sea'],
#  ['her',
#   'mother',
#   'died',
#   'birthing',
#   'brother',
#   'viserys',
#   'never',
#   'page',
#   'forgiven'],
#  ['she', 'remember', 'dragonstone', 'either'],
#  ['they', 'run', 'usurper', 'brother', 'set', 'sail', 'new', 'built', 'fleet'],
#  ['by',
#   'dragonstone',
#   'ancient',
#   'seat',
#   'house',
#   'remained',
#   'seven',
#   'kingdoms'],
#  ['it', 'would', 'remain', 'long'],
#  ['the',
#   'garrison',
#   'prepared',
#   'sell',
#   'usurper',
#   'one',
#   'night',
#   'ser',
#   'willem',
#   'darry',
#   'four',
#   'loyal',
#   'men',
#   'broken',
#   'nursery',
#   'stolen',
#   'along',
#   'wet',
#   'nurse',
#   'set',
#   'sail',
#   'cover',
#   'darkness',
#   'safety',
#   'braavosian',
#   'coast'],
#  ['she',
#   'remembered',
#   'ser',
#   'willem',
#   'dimly',
#   'great',
#   'grey',
#   'bear',
#   'man',
#   'halfblind',
#   'roaring',
#   'bellowing',
#   'orders',
#   'sickbed'],
#  ['the', 'servants', 'lived', 'terror', 'always', 'kind', 'dany'],
#  ['he',
#   'called',
#   'little',
#   'princess',
#   'sometimes',
#   'my',
#   'lady',
#   'hands',
#   'soft',
#   'old',
#   'leather'],
#  ['he',
#   'never',
#   'left',
#   'bed',
#   'though',
#   'smell',
#   'sickness',
#   'clung',
#   'day',
#   'night',
#   'hot',
#   'moist',
#   'sickly',
#   'sweet',
#   'odor'],
#  ['that', 'lived', 'braavos', 'big', 'house', 'red', 'door'],
#  ['dany', 'room', 'lemon', 'tree', 'outside', 'window'],
#  ['after',
#   'ser',
#   'willem',
#   'died',
#   'servants',
#   'stolen',
#   'little',
#   'money',
#   'left',
#   'soon',
#   'put',
#   'big',
#   'house'],
#  ['dany', 'cried', 'red', 'door', 'closed', 'behind', 'forever'],
#  ['they',
#   'wandered',
#   'since',
#   'braavos',
#   'myr',
#   'myr',
#   'tyrosh',
#   'qohor',
#   'volantis',
#   'lys',
#   'never',
#   'staying',
#   'long',
#   'one',
#   'place'],
#  ['her', 'brother', 'would', 'allow'],
#  ['the',
#   'usurper',
#   'hired',
#   'knives',
#   'close',
#   'behind',
#   'insisted',
#   'though',
#   'dany',
#   'never',
#   'seen',
#   'one'],
#  ['at',
#   'first',
#   'magisters',
#   'archons',
#   'merchant',
#   'princes',
#   'pleased',
#   'welcome',
#   'last',
#   'targaryens',
#   'homes',
#   'tables',
#   'years',
#   'passed',
#   'usurper',
#   'continued',
#   'sit',
#   'upon',
#   'iron',
#   'throne',
#   'doors',
#   'closed',
#   'lives',
#   'grew',
#   'meaner'],
#  ['years',
#   'past',
#   'forced',
#   'sell',
#   'last',
#   'treasures',
#   'even',
#   'coin',
#   'gotten',
#   'mother',
#   'crown',
#   'gone'],
#  ['in',
#   'alleys',
#   'wine',
#   'sinks',
#   'pentos',
#   'called',
#   'brother',
#   'beggar',
#   'king'],
#  ['dany', 'want', 'know', 'called'],
#  ['we', 'back', 'someday', 'sweet', 'sister', 'would', 'promise'],
#  ['sometimes', 'hands', 'shook', 'talked'],
#  ['the',
#   'jewels',
#   'silks',
#   'dragonstone',
#   'king',
#   'landing',
#   'iron',
#   'throne',
#   'seven',
#   'kingdoms',
#   'taken',
#   'us',
#   'back'],
#  ['viserys', 'lived', 'day'],
#  ['all',
#   'daenerys',
#   'wanted',
#   'back',
#   'big',
#   'house',
#   'red',
#   'door',
#   'lemon',
#   'tree',
#   'outside',
#   'window',
#   'childhood',
#   'never',
#   'known'],
#  ['there', 'came', 'soft', 'knock', 'door'],
#  ['come', 'dany', 'said', 'turning', 'away', 'window'],
#  ['illyrio', 'servants', 'entered', 'bowed', 'set', 'business'],
#  ['they', 'slaves', 'gift', 'one', 'magister', 'many', 'dothraki', 'friends'],
#  ['there', 'slavery', 'free', 'city', 'pentos'],
#  ['nonetheless', 'slaves'],
#  ['the',
#   'old',
#   'woman',
#   'small',
#   'grey',
#   'mouse',
#   'never',
#   'said',
#   'word',
#   'girl',
#   'made'],
#  ['she',
#   'illyrio',
#   'favorite',
#   'fair',
#   'haired',
#   'blue',
#   'eyed',
#   'wench',
#   'sixteen',
#   'chattered',
#   'constantly',
#   'worked'],
#  ['they',
#   'filled',
#   'bath',
#   'hot',
#   'water',
#   'brought',
#   'kitchen',
#   'scented',
#   'fragrant',
#   'oils'],
#  ['the',
#   'girl',
#   'pulled',
#   'rough',
#   'cotton',
#   'tunic',
#   'dany',
#   'head',
#   'helped',
#   'tub'],
#  ['the', 'water', 'scalding', 'hot', 'daenerys', 'flinch', 'cry'],
#  ['she', 'liked', 'heat'],
#  ['it', 'made', 'feel', 'clean'],
#  ['besides', 'brother', 'often', 'told', 'never', 'hot', 'targaryen'],
#  ['ours', 'house', 'dragon', 'would', 'say'],
#  ['the', 'fire', 'blood'],
#  ['the',
#   'old',
#   'woman',
#   'washed',
#   'long',
#   'silver',
#   'pale',
#   'hair',
#   'gently',
#   'combed',
#   'snags',
#   'silence'],
#  ['the', 'girl', 'scrubbed', 'back', 'feet', 'told', 'lucky'],
#  ['drogo', 'rich', 'even', 'slaves', 'page', 'wear', 'golden', 'collars'],
#  ['hundred',
#   'thousand',
#   'men',
#   'ride',
#   'khalasar',
#   'palace',
#   'vaes',
#   'dothrak',
#   'two',
#   'hundred',
#   'rooms',
#   'doors',
#   'solid',
#   'silver'],
#  ['there',
#   'like',
#   'much',
#   'handsome',
#   'man',
#   'khal',
#   'tall',
#   'fierce',
#   'fearless',
#   'battle',
#   'best',
#   'rider',
#   'ever',
#   'mount',
#   'horse',
#   'demon',
#   'archer'],
#  ['daenerys', 'said', 'nothing'],
#  ...]

# %%
model = gensim.models.Word2Vec(
    window=7,
    min_count=2,
    workers = 8,
    vector_size=200,
    epochs=10
)

# %%
model.build_vocab(story)

# %%
model.train(story,total_examples=model.corpus_count, epochs=model.epochs)
# Out:
# (9620056, 10171670)

# %%
model.corpus_count
# Out:
# 145020

# %%
model.epochs
# Out:
# 10

# %%
model.wv['throne']
# Out:
# array([-0.47144243,  1.8222377 , -0.01701978,  0.5815468 , -1.2699802 ,
#        -0.5434492 ,  0.01394445,  1.8048418 , -0.30800897, -1.4488308 ,
#         1.1913543 , -0.15685055, -0.19018734,  0.32865387,  0.26003033,
#        -0.07090744,  1.1873806 ,  0.03001888,  1.245018  , -0.5899149 ,
#        -0.15805873, -1.9855598 , -0.73350406,  0.3232527 , -1.3473248 ,
#         0.6379083 ,  2.0247092 , -1.3130466 , -0.58104914,  0.15263584,
#         0.5519662 ,  0.71821743, -0.44859672,  1.1745316 , -0.0165782 ,
#         1.0727837 ,  0.82586247, -0.178829  , -0.03778588, -1.2085943 ,
#        -0.83738625,  0.6195911 , -1.8733486 , -0.89184755, -0.01685759,
#         0.5768822 ,  1.4527457 , -0.4485128 ,  1.5916449 ,  0.8431062 ,
#         0.43848434, -0.08957399, -1.494962  , -0.52395236,  0.43054387,
#         0.9762932 ,  0.9168243 ,  0.73843884, -1.1147451 ,  0.2953404 ,
#         1.6419786 , -0.9701252 ,  0.8323469 , -0.8574768 , -0.30448434,
#         0.22773093, -0.82011646, -1.1321231 ,  1.2894008 , -0.37991762,
#        -1.1586908 , -0.7841333 , -0.24111296,  1.1528101 , -0.05948648,
#        -0.07368951, -0.9018358 ,  1.2588992 , -0.4379928 , -0.36228803,
#         1.8330168 ,  0.6372136 ,  0.8576237 , -0.60065204,  0.25395912,
#         0.83459234, -0.5558405 ,  1.7225838 ,  0.75796497, -0.32690203,
#         0.6482796 , -0.22472164, -0.5066776 , -0.3052891 , -1.651091  ,
#         1.2677923 ,  1.2033615 , -1.3647978 , -1.5175618 , -1.4234412 ,
#        -1.0211718 ,  0.8709308 ,  0.12794085, -0.02902644,  0.7961996 ,
#        -0.17865168, -0.6009889 ,  1.2530876 , -0.27647108, -1.4252385 ,
#        -0.08058592,  1.0830461 ,  1.8619715 , -0.28652188,  1.0510621 ,
#        -0.47225758,  1.163916  , -0.54423237,  2.3062472 ,  2.7219577 ,
#         0.53834045, -0.3839684 , -1.0881392 , -2.2506955 , -0.47346595,
#        -0.3046798 ,  0.14629902,  0.693449  , -0.4542214 ,  0.964381  ,
#        -2.0585911 ,  0.05407906, -0.94900686, -0.48162562, -1.0564203 ,
#         1.0793211 ,  0.6486452 ,  0.34220082,  0.21564475,  0.4171978 ,
#        -0.5330401 , -0.68052953,  0.72788036, -0.732806  , -2.4262185 ,
#        -0.8772322 , -1.5234632 , -1.7412556 ,  0.01066326, -0.59469914,
#        -0.01934374, -0.9786032 , -1.7571051 , -0.9131914 , -0.49895525,
#        -0.2872285 ,  1.5809295 ,  1.010977  , -1.0560488 , -0.710169  ,
#        -0.13457085, -0.01007688,  0.50890124, -1.1899276 , -0.22353764,
#        -0.22934622,  0.21192572, -2.78595   , -0.6162164 ,  1.0429959 ,
#        -1.1299785 , -1.32157   , -1.9825792 , -0.60230535, -0.05875908,
#         0.47221425, -1.0661751 , -0.735663  , -0.1193745 , -0.96510774,
#        -1.0954487 ,  0.9309561 ,  0.71962214, -0.04107879, -0.5089596 ,
#         0.6255338 , -1.1876068 ,  0.38354042, -0.4651244 ,  0.5496497 ,
#        -0.71866655, -0.313951  ,  0.6779594 , -2.3247414 , -1.052011  ,
#         1.0029534 , -0.98959506, -0.38723838, -0.31885627,  0.43471882],
#       dtype=float32)

# %%
len(model.wv['throne'])
# Out:
# 200

# %%
model.wv.similarity('jaime','sansa')
# Out:
# 0.47291413

# %%
model.wv.most_similar('king')
# Out:
# [('baratheon', 0.6214966177940369),
#  ('realm', 0.56524258852005),
#  ('feinting', 0.5379247665405273),
#  ('site', 0.5316070914268494),
#  ('usurper', 0.5302594304084778),
#  ('royal', 0.5013707280158997),
#  ('tourney', 0.48410817980766296),
#  ('throne', 0.4793712794780731),
#  ('mng', 0.47894051671028137),
#  ('dragonstone', 0.4777819514274597)]

# %%
# model.wv.doesnt_match()
