# %%
import gensim

# %%
from gensim import downloader

# %% [markdown]
# # Downloading a pretrain word2vec original google model

# %%
model = downloader.load('word2vec-google-news-300')

# %%
len(model['cricket'])
# Out:
# 300

# %%
from gensim.models import Word2Vec, KeyedVectors

# %%
# !pip install wget "https://github.com/mmihaltz/word2vec-GoogleNews-vectors.git"

# %%
model.most_similar('men')
# Out:
# [('women', 0.767493724822998),
#  ('Men', 0.6301247477531433),
#  ('males', 0.6242231130599976),
#  ('mens', 0.5807526707649231),
#  ('boys', 0.5781347751617432),
#  ('man', 0.5489763021469116),
#  ('females', 0.5481874346733093),
#  ('teenagers', 0.5462744832038879),
#  ('girls', 0.540932834148407),
#  ('ladies', 0.5234237909317017)]

# %%
model.most_similar('facebook')
# Out:
# [('Facebook', 0.7563533186912537),
#  ('FaceBook', 0.7076998949050903),
#  ('twitter', 0.6988552212715149),
#  ('myspace', 0.6941817998886108),
#  ('Twitter', 0.664244532585144),
#  ('twitter_facebook', 0.6572229862213135),
#  ('Facebook.com', 0.6529868245124817),
#  ('myspace_facebook', 0.6370643973350525),
#  ('facebook_twitter', 0.6367618441581726),
#  ('linkedin', 0.6356592774391174)]

# %%
model.similarity('sunny','man')
# Out:
# 0.1621465

# %%
model.similarity('python', 'java')
# Out:
# 0.12539075

# %%
model.similarity('php', 'python')
# Out:
# 0.18003926

# %%
model.doesnt_match(["PHP", "JAVA", "DOG", "PYTHON"])
# Out:
# 'PHP'

# %%
vec = model['king']-model['man']+model['woman']

# %%
model.most_similar(vec)
# Out:
# [('king', 0.8449392318725586),
#  ('queen', 0.7300517559051514),
#  ('monarch', 0.645466148853302),
#  ('princess', 0.6156251430511475),
#  ('crown_prince', 0.5818676352500916),
#  ('prince', 0.5777117609977722),
#  ('kings', 0.5613663792610168),
#  ('sultan', 0.5376775860786438),
#  ('Queen_Consort', 0.5344247817993164),
#  ('queens', 0.5289887189865112)]

# %% [markdown]
# # Training our own word2vec model
