# %% [markdown]
# # Tuple

# %%
t1 = (1,2,3,4)

# %%
type(t1)
# Out:
# tuple

# %%
5 + -5
# Out:
# 0

# %%
5 + --5
# Out:
# 10

# %%
5 + (15)
# Out:
# 20

# %%
t2 = 5

# %%
type(t2)
# Out:
# int

# %%
t2 = (5)

# %%
type(t2)
# Out:
# int

# %%
t3 = (5,)

# %%
type(t3)
# Out:
# tuple

# %%
t3
# Out:
# (5,)

# %%
t4 = tuple(5)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-14-cb0e3f4f24a8> in <cell line: 1>()
# ----> 1 t4 = tuple(5)
#
# TypeError: 'int' object is not iterable

# %%
print(t3)
print(type(t3))
# Out:
# (5,)
# <class 'tuple'>

# %%
print(t2)
print(type(t2))
# Out:
# 5
# <class 'int'>

# %%
t2 + t3
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-17-6d2e2ed25452> in <cell line: 1>()
# ----> 1 t2 + t3
#
# TypeError: unsupported operand type(s) for +: 'int' and 'tuple'

# %%
5 + (5)
# Out:
# 10

# %%
5 + (5,)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-19-7971d8895099> in <cell line: 1>()
# ----> 1 5 + (5,)
#
# TypeError: unsupported operand type(s) for +: 'int' and 'tuple'

# %%
li = [5]

for i in li:
    print(i)
# Out:
# 5

# %%
t10 = tuple(li)

# %%
t10
# Out:
# (5,)

# %%
t11 = (1,2,3,4)
t12 = (1,"mayank",5,10,[1,2])

# %%
print(t11)
print(t12)
print(type(t11))
print(type(t12))
# Out:
# (1, 2, 3, 4)
# (1, 'mayank', 5, 10, [1, 2])
# <class 'tuple'>
# <class 'tuple'>

# %%
t11[1]
# Out:
# 2

# %%
t12[4][0]
# Out:
# 1

# %%
t13  = [1,1]

# %%
t13
# Out:
# [1, 1]

# %%
t11[-1]
# Out:
# 4

# %%
print(t11)
print(t12)
# Out:
# (1, 2, 3, 4)
# (1, 'mayank', 5, 10, [1, 2])

# %%
t11[2] = 5
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-30-9ccefca992b6> in <cell line: 1>()
# ----> 1 t11[2] = 5
#
# TypeError: 'tuple' object does not support item assignment

# %%
t12[4] = [1,2,3]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[41], line 1
# ----> 1 t12[4] = [1,2,3]
#
# TypeError: 'tuple' object does not support item assignment

# %%
t14 = (1,2,3,[[1,2],3])

# %%
t14[3][0][1] = 1

# %%
t14
# Out:
# (1, 2, 3, [[1, 1], 3])

# %%
t14 = (1,2,3)

# %%
t14 = t12[0:2]

# %%
t14
# Out:
# (1, 'mayank')

# %%
t5 = ((1,2),3,4)

# %% [markdown]
# ### how things stored in tupple

# %%
l1 = [1,2]

# %%
for i in l1:
  print(id(i))
# Out:
# 133744684892400
# 133744684892432

# %%
li[1] = 3

# %%
l3 = [3,4]

# %%
id(l3)
# Out:
# 133744255732352

# %%
l2 = [1,2]

# %%
id(l2)
# Out:
# 133744255841280

# %%
newTuple = ( [1,2] , [5,[3,4]])

# %%
for i in newTuple:
    print(id(i))
# Out:
# 133743778227968
# 133743778227264

# %%
tl1 = newTuple[0]

# %%
tl2 = newTuple[1]

# %%
id(tl1)
# Out:
# 133743778227968

# %%
id(tl2)
# Out:
# 133743778227264

# %%
newTuple[0] = [1,2]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-55-6be020eaa2a0> in <cell line: 1>()
# ----> 1 newTuple[0] = [1,2]
#
# TypeError: 'tuple' object does not support item assignment

# %%
tl2
# Out:
# [5, [3, 4]]

# %%
id(tl2)
# Out:
# 4591108544

# %%
for i in tl2:
    print(id(i))
# Out:
# 4339770712
# 4587997440

# %%
tl2[1] = [5,3,5]

# %%
tl2
# Out:
# [5, [5, 3, 5]]

# %%
id(tl2)
# Out:
# 4591108544

# %%
newTuple
# Out:
# ([1, 2], [5, [5, 3, 5]])

# %%
t15 = (1,2,3,[[5,6],9], [9,10])

# %%
t15
# Out:
# (1, 2, 3, [[5, 6], 9], [9, 10])

# %%
id(1)
# Out:
# 133744684892400

# %%
for i in t15:
    print(id(i))
# Out:
# 133744684892400
# 133744684892432
# 133744684892464
# 133744477055936
# 133743778381120

# %%
t15[3][0][1] = 15

# %%
t15
# Out:
# (1, 2, 3, [[5, 15], 9], [9, 10])

# %%
for i in t15:
    print(id(i))
# Out:
# 133744684892400
# 133744684892432
# 133744684892464
# 133744477055936
# 133743778381120

# %%
t15[1] = 15
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-63-bd33fbe679c6> in <cell line: 1>()
# ----> 1 t15[1] = 15
#
# TypeError: 'tuple' object does not support item assignment

# %%
t15[4]  = [11,20]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-64-79283cffca6a> in <cell line: 1>()
# ----> 1 t15[4]  = [11,20]
#
# TypeError: 'tuple' object does not support item assignment

# %%
li = [1,2,3,t15]

# %%
li
# Out:
# [1, 2, 3, (1, 2, 3, [[5, 15], 9], [9, 10])]

# %%
li[3]
# Out:
# (1, 2, 3, [[5, 15], 9], [9, 10])

# %% [markdown]
# # packing and unpacking

# %%
a = 1,2,3,4

# %%
a
# Out:
# (1, 2, 3, 4)

# %%
w,x,y,z = a

# %%
print(w,x,y,z)
# Out:
# 1 2 3 4

# %% [markdown]
# # Function for tupple

# %% [markdown]
# 1. len()
# 2. max()
# 3. min()
# 4. sum()
# 5. sorted()
# 6. any()
# 7. all()
# 8. tuple()

# %%
# restart kernel

# %%
t1 = (1,2,3,4)
t2 = (1,"python",5.0,True)
t3 = ('a','b','c')

# %%
1 in t1
# Out:
# True

# %% [markdown]
# # len

# %%
len(t1)
# Out:
# 4

# %% [markdown]
# # SUM

# %%
sum(t1)
# Out:
# 10

# %%
sum(t2)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-5-3fd5fddf4b2a> in <cell line: 1>()
# ----> 1 sum(t2)
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'

# %% [markdown]
# # min

# %%
min (t1)
# Out:
# 1

# %%
min (t2)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-7-0086dcc63454> in <cell line: 1>()
# ----> 1 min (t2)
#
# TypeError: '<' not supported between instances of 'str' and 'int'

# %% [markdown]
# # max

# %%
max(t1)
# Out:
# 4

# %%
max(t2)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-9-c4f83a43986d> in <cell line: 1>()
# ----> 1 max(t2)
#
# TypeError: '>' not supported between instances of 'str' and 'int'

# %%
max(t3)
# Out:
# 'c'

# %% [markdown]
# # sum

# %%
sum(t1)
# Out:
# 10

# %%
sum(t2)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-12-3fd5fddf4b2a> in <cell line: 1>()
# ----> 1 sum(t2)
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'

# %%
t3
# Out:
# ('a', 'b', 'c')

# %%
sum(t3)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-14-93785e328ea8> in <cell line: 1>()
# ----> 1 sum(t3)
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'

# %%
t4 = [0j,1 ,'mayank']

# %%
any(t3)
# Out:
# True

# %%
any(t4)
# Out:
# True

# %%
all(t4)
# Out:
# False

# %% [markdown]
# # Concatenation in Tupple

# %%
t1
# Out:
# (1, 2, 3, 4)

# %%
t2
# Out:
# (1, 'python', 5.0, True)

# %%
t5 = t1+t2

# %%
t5
# Out:
# (1, 2, 3, 4, 1, 'python', 5.0, True)

# %%
id(t1)
# Out:
# 132405926315408

# %%
t1 = t1+ t2

# %%
id(t2)
# Out:
# 132405708403024

# %%
t1
# Out:
# (1, 2, 3, 4, 1, 'python', 5.0, True)

# %%
id(t1)
# Out:
# 132405708124032

# %%
t2* 3
# Out:
# (1, 'python', 5.0, True, 1, 'python', 5.0, True, 1, 'python', 5.0, True)

# %%
a = (1,2,3,7)
b = (4,5,6)

# %%
a>b
# Out:
# False

# %%
a = ('a','b','c')
b = ('x',)

# %%
a > b
# Out:
# False

# %%
ord('x')
# Out:
# 120

# %%
ord('a')
# Out:
# 97

# %% [markdown]
# I had a doubt. If I define a=('b', 'c') and I add sum(a), why it is not adding the lexographical values wheres it can compare a>b lexographically?

# %%
a = ('b','c')

# %%
sum(a)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[49], line 1
# ----> 1 sum(a)
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'

# %%
'b' +'d'+ 'c'
# Out:
# 'bdc'

# %% [markdown]
# # sorted

# %%
sorted(t1)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-36-4da6b23c2c8b> in <cell line: 1>()
# ----> 1 sorted(t1)
#
# TypeError: '<' not supported between instances of 'str' and 'int'

# %%
t1 = (1,2,3,4)
t2 = (1,"python",5.0,True)
t3 = ('a','b','c')

# %%
tuple(sorted(t1))
# Out:
# (1, 2, 3, 4)

# %%
sorted(t3,reverse=True)
# Out:
# ['c', 'b', 'a']

# %% [markdown]
# # methods in Tupple

# %%
1. Append() # not possible
2. extend() #not possible
3. Insert() # not possible
4. index()
5. count()
6. Remove() # not possible
7. pop()   # not possible
8. clear()
9. reverse()
10. sort()
11. Copy()

# %%
t1 = (1,2,3,4)
t2 = (1,"python",5.0,True)
t3 = ('a','b','c')

# %%
t1.extend(t2)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[62], line 1
# ----> 1 t1.extend(t2)
#
# AttributeError: 'tuple' object has no attribute 'extend'

# %%
t1.clear()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[63], line 1
# ----> 1 t1.clear()
#
# AttributeError: 'tuple' object has no attribute 'clear'

# %%
del(t1)

# %%
t1
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-41-5db19043943a> in <cell line: 1>()
# ----> 1 t1
#
# NameError: name 't1' is not defined

# %%
t2
# Out:
# (1, 'python', 5.0, True)

# %%
t2.count(1)
# Out:
# 2

# %%
t2.count(True)
# Out:
# 2

# %%
t2.index('python')
# Out:
# 1

# %%
t2.index(0)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[73], line 1
# ----> 1 t2.index(0)
#
# ValueError: tuple.index(x): x not in tuple

# %%
t2 = (5,1,2,3,5,6,5)

# %%
t2.index(5) - len(t2)
# Out:
# -2

# %%
t2[-7]
# Out:
# 5

# %%
t2.index(5,5) - len(t2)
# Out:
# -1
