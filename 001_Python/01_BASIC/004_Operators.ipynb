# %%
P="PYTHON"
P[2:2]
# Out:
# ''

# %% [markdown]
# # Assignment Operators

# %%
a = 10

# %%
print(a)
# Out:
# 10

# %%
a, b = 10 ,20
print(a,b)
# Out:
# 10 20

# %%
a = b= c = 40
print(a,b,c)
# Out:
# 40 40 40

# %%
a,b = 10
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-6-e0e8d72773ec> in <cell line: 1>()
# ----> 1 a,b = 10
#       2
#
# TypeError: cannot unpack non-iterable int object

# %%
a,b = 10,10

# %%
a=b=10

# %%
a,b,c = 10,20,30,40
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-9-ca145015aa16> in <cell line: 1>()
# ----> 1 a,b,c = 10,20,30,40
#
# ValueError: too many values to unpack (expected 3)

# %% [markdown]
# # Compound  Assignment Operators

# %%
x = 10
x= x + 5
x
# Out:
# 15

# %%
x = 10
x+=5
x
# Out:
# 15

# %%
x *= 10
x
# Out:
# 150

# %%
x /=10
x
# Out:
# 15.0

# %%
x**=2
x
# Out:
# 225.0

# %%
x = x//9
x
# Out:
# 25.0

# %%
x //= 5
x
# Out:
# 1.0

# %%
x = 15
x = x**2   # equal to x**=2

# %%
x = x//5  #  eqaul to x//=5

# %%
y=100

# %%
y = y // 10
y
# Out:
# 10

# %%
y = 100

y //=10
y
# Out:
# 10

# %%
z = 9

z//2
# Out:
# 4

# %%
c = 10

c++
# Out:
#   File "<ipython-input-24-f13fdbffd16f>", line 3
#     c++
#        ^
# SyntaxError: invalid syntax

# %%
c = 10
c+=1
c
# Out:
# 11

# %%
c+=c

# %%
c
# Out:
# 22

# %%
m = 10

# %%
++m
# Out:
# 10

# %%
m++5
# Out:
# 15

# %%
m
# Out:
# 10

# %%
n = -10

# %%
-n
# Out:
# 10

# %%
j = 10

--j
# Out:
# 10

# %%
j
# Out:
# 10

# %%
---j
# Out:
# -10

# %%
j--
# Out:
#   File "<ipython-input-37-65b73748a70d>", line 1
#     j--
#        ^
# SyntaxError: invalid syntax

# %%
j
# Out:
# 10

# %%
j+-5
# Out:
# 5

# %%
j
# Out:
# 10

# %%
# Have restarted kernel

# %% [markdown]
# # Identity Operators

# %%
a = 10
id(a)
# Out:
# 132363117396496

# %%
m = "mayank"
id(m)
# Out:
# 132362687637168

# %%
b =2
id(b)
# Out:
# 132363117396240

# %%
c =2
id(c)
# Out:
# 132363117396240

# %%
ans = b is c
ans
# Out:
# True

# %%
id(b) == id(c)
# Out:
# True

# %%
c =3
id(c)
# Out:
# 132363117396272

# %%
ans = b is c
ans
# Out:
# False

# %%
id(b) == id(c)
# Out:
# False

# %%
a,b = [1e10,1e10]

# %%
id(a)
# Out:
# 132362688872144

# %%
id(b)
# Out:
# 132362688872144

# %%
a ,b =2,3
a is b
# Out:
# False

# %%
m=2
n=2
m is not n
# Out:
# False

# %%
id(m)
# Out:
# 132363117396240

# %%
id(n)
# Out:
# 132363117396240

# %%
n = 6

# %%
id(n)
# Out:
# 132363117396368

# %%
x = 2

type(x) is float
# Out:
# False

# %%
s1 = 'BLR'
s2 = 'blr'

s1 is not s2
# Out:
# True

# %%
s3 = 'BLR'

s1 is not s3
# Out:
# False

# %%
type(s1) is str
# Out:
# True

# %%
s4 = 'BL R'

s1 is s4
# Out:
# False

# %%
# kerner restarted

# %% [markdown]
# # Membership Operators
#
# # in and not in

# %%
m = "mayank"

a = "a"

# %%
a in m
# Out:
# True

# %%
"i" in m
# Out:
# False

# %%
"" in m
# Out:
# True

# %%
" " in m
# Out:
# False

# %%
"ay" in m
# Out:
# True

# %%
primes = [2,3,5,7,11]

# %%
3 in primes
# Out:
# True

# %%
0  in primes
# Out:
# False

# %%
[2,5,3] in primes
# Out:
# False

# %%
a = 2
b=3
c=4
d=5
e=6

a=b+c
d=a+e

# %%
b
# Out:
# 3

# %%
d
# Out:
# 13

# %%
b in d
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-8-a42d63895dd6> in <cell line: 1>()
# ----> 1 b in d
#
# TypeError: argument of type 'int' is not iterable

# %%
m = [2,6,7,9,[2,6]]
 # [2,6] in m, why this is give false even subset within list

    ## bag in bag analogy for intuition

# %%
[2,6] in m
# Out:
# True

# %%
ans = 25/(2+3)**2
ans
# Out:
# 1.0

# %%
2 ** 3 ** 2
# Out:
# 512
