# %% [markdown]
# # Decision Flow

# %%
def power(x):
    print(x**2)

# %%
val = int(input("enter a number"))
# Out:
# enter a number2

# %%
power(2) ## always executed
# Out:
# 4

# %%
# power(3) # not writing, not getting executed.

# %%
ans =power(7)
# Out:
# 49

# %%
val = int(input("enter a number"))
# Out:
# enter a number7

# %%
ans = 0

if val %2 ==0:
    ans = power(5)
else:
    ans = power(10)

ans
# Out:
# 100

# %% [markdown]
# # if statement

# %%
if True:
    print("Hello")
# Out:
# Hello

# %%
if False:
    print("Hello")

# %%
if -1:
    print("Yo")

print(True,False)
# Out:
# Yo
# True False

# %%
if 0 and None and 0.0 :
    print("Yo")

# %%
if 1 or 0:
    print("Yo")
# Out:
# Yo

# %%
m = 5
n= "mayank"

# %%
m
# Out:
# 5

# %%
if type(m) == int:
    print("i got a integer")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-13-2865c2dbcf26> in <cell line: 1>()
# ----> 1 if type(m) == int:
#       2     print("i got a integer")
#
# NameError: name 'm' is not defined

# %%
inp = input("Enter a number")
# Out:
# Enter a number

# %%
inp
# Out:
# ''

# %%
type(inp)
# Out:
# str

# %%
if type(inp) == int:
    print ("500")

# %%
inp = int(input("Enter a number"))
# Out:
# Enter a number
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-18-73fc8bfae72b> in <cell line: 1>()
# ----> 1 inp = int(input("Enter a number"))
#
# ValueError: invalid literal for int() with base 10: ''

# %%
if type(inp) == int:
    print ("500")

# %%
 # WAP to check if input number from user is even

# %%
num = int(input())
# Out:
# 4

# %%
if num %2 ==0:
    print("Even")

if num %2 !=0:
    print("Odd")
# Out:
# Even

# %%
if num %2 ==0:
    print("here")
    print("Even")

print("here")
if num %2 !=0:
    print("Odd")
# Out:
# here
# Even
# here

# %%
num = int(input())
# Out:
# 4

# %%
if num %2==0:
    print("here")
print("Even")
    print("here")
else:
    print("here")
    print("Odd")
# Out:
#   File "<ipython-input-26-55fc6645065c>", line 4
#     print("here")
#     ^
# IndentationError: unexpected indent

# %% [markdown]
# # if elif else

# %%
stringInput = input()
# Out:
#  ga'

# %%
if stringInput == "apple":
    print("apple")
elif stringInput == "orange":
    print("orange")
elif stringInput == "banana":
    print("banana")
else:
    print("no fruit")
# Out:
# no fruit

# %% [markdown]
# # Nested if else

# %%
# Previous Function
def out2(stringInput,num):
    if stringInput  == "apple":
        if num == 2:
            print("100")
        elif num == 3:
            print ("200")
    elif stringInput == "orange":
        if num == 5:
            print("500")
        elif num == 8:
            print ("600")

# %%
def out(stringInput,num):
    if stringInput  == "apple" :
        if num == 2:
            print("100")
        elif num == 3:
            print ("200")
    elif stringInput == "orange":
        if num == 5:
            print("500")
        elif num == 8:
            print ("600")
        else:
            print("1000")
    else:
        print("2000")

# %%
out("dragonfruit",9)
# Out:
# 2000

# %%
out2("orange",8)
# Out:
# 600

# %%
out2("orange","5")

# %%
out2("apple",2)
# Out:
# Everything OK

# %%
out2("apple",3)
# Out:
# Still ok

# %%
out2("apple",6)

# %%
out2("orange","5")

# %% [markdown]
# # WAP = Write a program

# %% [markdown]
# # WAP to accept 3 integers from the user and without using any logical operator and cascading of relational operators ( means combining of different operators i.e. you cannot say like this a >b>c or a>b and a>c) , find out the greatest number amongst them

# %% [markdown]
# # WAP to accept an year from the user and check whether it is a leap year or not
