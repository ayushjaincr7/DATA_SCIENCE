# %% [markdown]
# # Set

# %%
s1 = {1,2,3,1}

# %%
s1
# Out:
# {1, 2, 3}

# %%
s1[0]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-3-bfed54b371ac> in <cell line: 1>()
# ----> 1 s1[0]
#
# TypeError: 'set' object is not subscriptable

# %%
type(s1)
# Out:
# set

# %%
s1[0] = 5
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-6-6764e43fc5f0> in <cell line: 1>()
# ----> 1 s1[0] = 5
#
# TypeError: 'set' object does not support item assignment

# %%
# str list tuple range

set([1,1,2,3,1,4,6])
# Out:
# {1, 2, 3, 4, 6}

# %% [markdown]
# # set is Iterable but not ordered

# %%
# sir jaise apne set banaya h tuple use krke vaise tuple bna skte h set use krke??


# set is Iterable but not ordered
for i in s1:
    print(i)
# Out:
# 1
# 2
# 3

# %%
# Creating a set with unordered elements
my_set = {3, 1, 2, 5, 4}

# Adding more elements to the set
my_set.add(6)
my_set.add(0)

# Iterating over the set
print("Elements in the set:")
for element in my_set:
    print(element)
# Out:
# Elements in the set:
# 0
# 1
# 2
# 3
# 4
# 5
# 6

# %%
for i in range(0,len(s1)):
    print(s1[i])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-25-fc16594fe9d4> in <cell line: 1>()
#       1 for i in range(0,len(s1)):
# ----> 2     print(s1[i])
#
# TypeError: 'set' object is not subscriptable

# %%
tuple(s1)
# Out:
# (1, 2, 3)

# %%
s2 = {4,5,6,1,31,True}

# %%
len(s2)
# Out:
# 5

# %%
s2
# Out:
# {1, 4, 5, 6, 31}

# %%
s3 = set((1,2,3))
len(s3)
# Out:
# 3

# %%
s3 = set((1,2,3))

# %%
s3
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 s3
#
# NameError: name 's3' is not defined

# %% [markdown]
# # Function for Set

# %%
s3.add('4')

# %%
s3

# %%
s5 = {1,2,True,"mayank"}

# %%
s5 = {1,2,True,"mayank"}

# %% [markdown]
# # Sets Method

# %% [markdown]
# 1. add()
# 2. clear()
# 3. copy()
# 4. pop()
# 5. remove()
# 6. difference()
# 7. Update()

# %% [markdown]
# # add

# %%
s5.add(3)

# %%
s5
# Out:
# {1, 2, 3, 'mayank'}

# %%
s5.add(1)

# %%
s5
# Out:
# {1, 2, 3, 'mayank'}

# %%
s5.add(True)

# %%
s5
# Out:
# {1, 2, 3, 'mayank'}

# %% [markdown]
# # copy

# %%
s6 = s5.copy()

# %%
s6
# Out:
# {1, 2, 3, 'mayank'}

# %%
print(id(s6))
print(id(s5))
# Out:
# 133754125792896
# 133754125792000

# %%
s5.add(65)

# %%
s6
# Out:
# {1, 2, 3, 'mayank'}

# %%
s5
# Out:
# {1, 2, 3, 65, 'mayank'}

# %%
s7 = s5

# %%
s7.add(64)

# %%
s5
# Out:
# {1, 2, 3, 64, 65, 'mayank'}

# %%
s8 = s5.copy()

# %%
for i in s5:
    print(id(i))
# Out:
# 133754553534672
# 133754553534704
# 133754553532656
# 133754553532688
# 133754553532720
# 133754123843952

# %%
for i in s8:
    print(id(i))
# Out:
# 133754553534672
# 133754553534704
# 133754553532656
# 133754553532688
# 133754553532720
# 133754123843952

# %%
print(id(s5))
print(id(s8))
# Out:
# 133754125792000
# 133754125792224

# %%
s8.add(5454)

# %%
s8
# Out:
# {1, 2, 3, 5454, 64, 65, 'mayank'}

# %%
s5
# Out:
# {1, 2, 3, 64, 65, 'mayank'}
