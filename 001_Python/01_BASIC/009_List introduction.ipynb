# %% [markdown]
# # List In Python

# %%
mylist1 = []

# %%
type(mylist1)
# Out:
# list

# %%
mylist2 = [1,2,3,4,5] # homogeneous

# %%
type(mylist2)
# Out:
# list

# %%
mylist3 = [1,"mayank",2.4,True,2+5j] # heterogenous List

# %%
2+5i
# Out:
#   File "<ipython-input-6-d80acb23181e>", line 1
#     2+5i
#       ^
# SyntaxError: invalid decimal literal

# %%
2+5j
# Out:
# (2+5j)

# %%
mylist3 = [1,"mayank",2.4,True,2+5j]

# %%
len(mylist3)
# Out:
# 5

# %%
print(mylist3)
# Out:
# [1, 'mayank', 2.4, True, (2+5j)]

# %%
def myLenFunc(l):
    length = 0
    for i in l:
        length+=1
    print(length)

# %%
myLenFunc(mylist3)
# Out:
# 5

# %%
int(mylist3)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-11-9e9bd077d80d> in <cell line: 1>()
# ----> 1 int(mylist3)
#
# TypeError: int() argument must be a string, a bytes-like object or a real number, not 'list'

# %%
mylist3
# Out:
# [1, 'mayank', 2.4, True, (2+5j)]

# %%
mylist3[0]
# Out:
# 1

# %% [markdown]
# # List elements are changable or can be modified

# %%
mylist3[2]
# Out:
# 2.4

# %%
mylist3[0] = 10000

# %%
mylist3
# Out:
# [10000, 'mayank', 2.4, True, (2+5j)]

# %%
myNewList = mylist3[0:2]

# %%
myNewList
# Out:
# [10000, 'mayank']

# %%
myNewList2 = mylist3[0:5:2]

# %%
myNewList2
# Out:
# [10000, 2.4, (2+5j)]

# %%
for i in mylist3:
    print (i)
# Out:
# 10000
# mayank
# 2.4
# True
# (2+5j)

# %%
for i in range(len(mylist3)):
    print (mylist3[i])
# Out:
# 10000
# mayank
# 2.4
# True
# (2+5j)

# %%
print(mylist3[i] for i in mylist3)
# Out:
# <generator object <genexpr> at 0x78d8804c4580>

# %% [markdown]
# # List Function

# %%
int()
float()
str()
complex()
bool()
# Out:
# False

# %%
li = list()

# %%
li
# Out:
# []

# %%
li2 = list("mayank")

# %%
li2
# Out:
# ['m', 'a', 'y', 'a', 'n', 'k']

# %%
li3= list(100)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-29-41568a41cc56> in <cell line: 1>()
# ----> 1 li3= list(100)
#
# TypeError: 'int' object is not iterable

# %%
for i in 100:
    print (i) # wrong
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-30-8f8d00a127af> in <cell line: 1>()
# ----> 1 for i in 100:
#       2     print (i) # wrong
#
# TypeError: 'int' object is not iterable

# %%
for i in "mayank":
    print(i)
# Out:
# m
# a
# y
# a
# n
# k

# %%
for i in 1:
    print (i) # wrong
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 for i in 1:
#       2     print (i)
#
# TypeError: 'int' object is not iterable

# %%
li3= list(5)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 li3= list(5)
#
# TypeError: 'int' object is not iterable

# %%
def mysum(a,b):
    print(a+b)

# %%
mysum(5,10)
# Out:
# 15

# %%
mysum(5,10,100)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 mysum(5,10,100)
#
# TypeError: mysum() takes 2 positional arguments but 3 were given

# %%
li4 = list((10,20,30))

# %%
li4
# Out:
# [10, 20, 30]

# %%
li5 = list((10,))  # for a single element

# %%
li5
# Out:
# [10]

# %%
# Indexing Slicing

# %%
li6 = list('m')

# %%
li7 = list(100)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-21-fb7184ab4815> in <cell line: 1>()
# ----> 1 li7 = list(100)
#
# TypeError: 'int' object is not iterable

# %%
li8 = [1,2,3,"mayank",5,8]

# %%
li8
# Out:
# [1, 2, 3, 'mayank', 5, 8]

# %%
li8[2]
# Out:
# 3

# %%
li8[3]
# Out:
# 'mayank'

# %%
type(li8[2])
# Out:
# int

# %%
type(li8[3])
# Out:
# str

# %%
myStr = 'Mayank'

# %%
myStr[2]
# Out:
# 'y'

# %%
li8[3][2]
# Out:
# 'y'

# %%
li8[3][2]
# Out:
# 'y'

# %%
type(li8[3])
# Out:
# str

# %%
li9 = [1,2,3,"mayank",5,8,["first","second"]]

# %%
type(li9[-1])
# Out:
# list

# %%
li9[-1][0]
# Out:
# 'first'

# %%
li9[-1][0][2]
# Out:
# 'r'

# %% [markdown]
# # Membership in List

# %%
li9
# Out:
# [1, 2, 3, 'mayank', 5, 8, ['first', 'second']]

# %%
2 in li9
# Out:
# True

# %%
'mayank' in li9
# Out:
# True

# %%
'Mayank' in li9
# Out:
# False

# %%
'first' in li9
# Out:
# False

# %%
['first','second'] in li9
# Out:
# True

# %%
'123' not in li9
# Out:
# True

# %%
reviews = ["good food", "bad food" , "great service", "bad service"]

# %%
service_reviews = []

for item in reviews:
    if 'service' in item:
        service_reviews.append(item)

# %%
service_reviews
# Out:
# ['great service', 'bad service']

# %%
email = ["abc@gmail.com","abc@gmail.com","abc@gmail.com","abc@gmail.com","abc@yahoo.com","abc@yahoo.com"]

# %%
gmail_accounts = []

for item in email:
    if 'gmail' in item:
        gmail_accounts.append(item)

# %%
gmail_accounts
# Out:
# ['abc@gmail.com', 'abc@gmail.com', 'abc@gmail.com', 'abc@gmail.com']

# %%
# why list('m') is working and list(123) not working?

# %%
list()
# Out:
# []

# %%
list(123)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-52-1c325c17b3d1> in <cell line: 1>()
# ----> 1 list(123)
#
# TypeError: 'int' object is not iterable

# %%
list('m')

# %% [markdown]
# # Methods Vs Function

# %%
len(email) # Function
# Out:
# 6

# %%
type(email)
# Out:
# list

# %%
email.append() # method
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-50-cee0b3f8d139> in <cell line: 1>()
# ----> 1 email.append() # method
#
# TypeError: list.append() takes exactly one argument (0 given)

# %% [markdown]
# # Functions
#
# 1. Len()
# 2. Max()
# 3. Min()
# 4. Sum()
# 5. sorted()
# 6. any()
# 7. all()
# 8. list()

# %%
newList = [1, 2531, 5310, 21, 513]

# %%
newList2 = [1,'mayank','python',True,513]

# %%
len(newList)
# Out:
# 5

# %%
max(newList)
# Out:
# 5310

# %%
max(newList2)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-55-a7723fba103c> in <cell line: 1>()
# ----> 1 max(newList2)
#
# TypeError: '>' not supported between instances of 'str' and 'int'

# %%
newList3 = [1,2,'3',4,'5']

# %%
max(newList3)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-57-16c28092bcbd> in <cell line: 1>()
# ----> 1 max(newList3)
#
# TypeError: '>' not supported between instances of 'str' and 'int'

# %%
mymax = 0
for item in newList3:
    if(mymax < int(item)):
        mymax = int(item)

# %%
mymax
# Out:
# 5

# %%
mystringList = ['a','b','c']

# %%
max(mystringList)
# Out:
# 'c'

# %%
min(newList)
# Out:
# 1

# %%
min(newList2)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-63-55ec01e932d7> in <cell line: 1>()
# ----> 1 min(newList2)
#
# TypeError: '<' not supported between instances of 'str' and 'int'

# %%
min(mystringList)
# Out:
# 'a'

# %%
print(newList)
print(newList2)
print(mystringList)
# Out:
# [1, 2531, 5310, 21, 513]
# [1, 'mayank', 'python', True, 513]
# ['a', 'b', 'c']

# %%
print(sum(newList))
#print(sum(newList2))
# Out:
# 8376

# %%
'5'+ '1'
# Out:
# '51'

# %%
mystringList
# Out:
# ['a', 'b', 'c']

# %%
print(sum(mystringList))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-69-2ceae31d6435> in <cell line: 1>()
# ----> 1 print(sum(mystringList))
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'

# %%
# sum of 'a' & 'b'

# %%
print(newList)
print(newList2)
print(mystringList)
# Out:
# [1, 2531, 5310, 21, 513]
# [1, 'mayank', 'python', True, 513]
# ['a', 'b', 'c']

# %%
# Sorted
sorted(newList)
# Out:
# [1, 21, 513, 2531, 5310]

# %%
sorted(newList2)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-72-60765d1a1067> in <cell line: 1>()
# ----> 1 sorted(newList2)
#
# TypeError: '<' not supported between instances of 'str' and 'int'

# %%
sorted(mystringList)
# Out:
# ['a', 'b', 'c']

# %%
# Sorted
sorted(newList,reverse=True)
# Out:
# [5310, 2531, 513, 21, 1]

# %%
sorted(mystringList,reverse=True)
# Out:
# ['c', 'b', 'a']

# %%
4 2 5

ascending = 2 4 5
descending = 5 4 2

# %%
print(newList)
print(newList2)
print(mystringList)
# Out:
# [1, 2531, 5310, 21, 513]
# [1, 'mayank', 'python', True, 513]
# ['a', 'b', 'c']

# %%
any(newList)
# Out:
# True

# %%
listtoexplainany = [0,0,0,False]

# %%
any(listtoexplainany)


# Return True if bool(x) is True for any x in the iterable.
# Out:
# False

# %%
listtoexplainany = [0,0,0,1]

# %%
any(listtoexplainany)
# Out:
# True

# %%
all(listtoexplainany)
# Out:
# False

# %%
list1 = [True,True,True,False]

# %%
any(list1)
# Out:
# True

# %%
all(list1)
# Out:
# False

# %%
list2 = [-1,0,False]

# %%
any(list2)
# Out:
# True

# %%
all(list2)
# Out:
# False

# %%
print(newList)
print(newList2)
print(mystringList)
# Out:
# [1, 2531, 5310, 21, 513]
# [1, 'mayank', 'python', True, 513]
# ['a', 'b', 'c']

# %%
print(any(newList))
print(any(newList2))
print(any(mystringList))
# Out:
# True
# True
# True

# %%
0 , 0.0 , None, 0+0j , [] False

# %%
# suppose neither 1 and true nor 0 and false are present then?

# %%
bool(-1)
# Out:
# True

# %%
# It is actually sorting the characters in a string.
# a = 'mayank'
# sorted(a) => ['a','a','k','m','n','y']
sorted()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-87-0e3411ec1b27> in <cell line: 4>()
#       2 # a = 'mayank'
#       3 # sorted(a) => ['a','a','k','m','n','y']
# ----> 4 sorted()
#
# TypeError: sorted expected 1 argument, got 0

# %%
# List Concatenation

# %%
l1 = ['a','b','c']

# %%
l2 = ['d','e','f']

# %%
l1+l2
# Out:
# ['a', 'b', 'c', 'd', 'e', 'f']

# %%
l1 * 3
# Out:
# ['a', 'b', 'c', 'a', 'b', 'c', 'a', 'b', 'c']

# %%
l1 +3
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-93-922beb35f6c0> in <cell line: 1>()
# ----> 1 l1 +3
#
# TypeError: can only concatenate list (not "int") to list

# %%
l1-3
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[148], line 1
# ----> 1 l1-3
#
# TypeError: unsupported operand type(s) for -: 'list' and 'int'

# %%
l1/3
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[149], line 1
# ----> 1 l1/3
#
# TypeError: unsupported operand type(s) for /: 'list' and 'int'

# %%
l1*l2
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-94-bd77ec8884ac> in <cell line: 1>()
# ----> 1 l1*l2
#
# TypeError: can't multiply sequence by non-int of type 'list'

# %%
l1-l2
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[151], line 1
# ----> 1 l1-l2
#
# TypeError: unsupported operand type(s) for -: 'list' and 'list'

# %%
l1/l2
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[152], line 1
# ----> 1 l1/l2
#
# TypeError: unsupported operand type(s) for /: 'list' and 'list'

# %%
l1+l2
# Out:
# ['a', 'b', 'c', 'd', 'e', 'f']

# %% [markdown]
# # List methods

# %%
1. Append()
2. extend()
3. Insert()
4. index()
5. count()
6. Remove()
7. pop()
8. clear()
9. reverse()
10. sort()
11. Copy()

# %%
l1.
# Out:
# ['a', 'b', 'c']

# %% [markdown]
# # append

# %%
l1.append('d')

# %%
l1
# Out:
# ['a', 'b', 'c', 'd']

# %% [markdown]
# # extend

# %%
l1.extend(l2)

# %%
l1
# Out:
# ['a', 'b', 'c', 'd', 'd', 'e', 'f']

# %%
l2.extend('may')

# %%
l2
# Out:
# ['d', 'e', 'f', 1, 2, 3, 'm', 'a', 'y', 1, 2, 3, 'may']

# %%
l2.extend([1,2,3])

# %%
l2
# Out:
# ['d', 'e', 'f', 1, 2, 3, 'm', 'a', 'y', 1, 2, 3, 'may', 'm', 'a', 'y', 1, 2, 3]

# %%
l2 + 'may'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[167], line 1
# ----> 1 l2 + 'may'
#
# TypeError: can only concatenate list (not "str") to list

# %%
l3 = list('9999999999')

# %%
l3.extend(l1)

# %%
l3
# Out:
# ['9',
#  '9',
#  '9',
#  '9',
#  '9',
#  '9',
#  '9',
#  '9',
#  '9',
#  '9',
#  'a',
#  'b',
#  'c',
#  'd',
#  'd',
#  'e',
#  'f']

# %% [markdown]
# # Insert

# %%
l1 = ['a','b','c']

# %%
l1.insert(2,'d')

# %%
l1
# Out:
# ['a', 'b', 'd', 'd', 'c']

# %%
l1.insert(1,'e')

# %%
l1
# Out:
# ['a', 'e', 'b', 'd', 'd', 'c']

# %%
# if we are giving beyond index, it adds to the end.
l1.insert(100,'f')

# %%
l1
# Out:
# ['a', 'e', 'b', 'd', 'd', 'c', 'f']

# %%
l1.insert(99,'abc')

# %%
l1
# Out:
# ['a', 'e', 'b', 'd', 'c', 'f', 'abc']

# %%
l1.insert(3,'def')

# %% [markdown]
# # index

# %%
l1
# Out:
# ['a', 'e', 'b', 'd', 'd', 'c', 'f', 'abc']

# %%
l4 = [1,2,3,2,1,6]

# %%
l4.index(5)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-126-bb8a999278cd> in <cell line: 1>()
# ----> 1 l4.index(5)
#
# ValueError: 5 is not in list

# %% [markdown]
# append - add the object value  at the end
# extend - will place the iterable value at the end, will throw error if a non iterable value passed.
# insert - will place the value in the index defined.
#        - even if the index passed while inserting is out of range python does not throw error but will add the value at the end.

# %% [markdown]
# # Count

# %%
l4.count(1)
# Out:
# 2

# %%
l4.count(5)
# Out:
# 0

# %% [markdown]
# # Remove

# %%
l4.remove(1) # 23216 or 2326
l4
# Out:
# [2, 3, 2, 6]

# %%
l4.remove(5)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[211], line 1
# ----> 1 l4.remove(5)
#
# ValueError: list.remove(x): x not in list

# %% [markdown]
# ### WAP to remove all occurence of 1 from the below list, don't create new list
#
# # givenList = [1,4,6,2,1,2,1,5,1,54,1,6]

# %%
givenList = [1,4,6,2,1,2,1,5,1,54,1,6]

# %%
c1 = givenList.count(1)

for i in range(c1):
    givenList.remove(1)
givenList
# Out:
# [4, 6, 2, 2, 5, 54, 6]

# %%
l = list(map(int,input().split()))
for i in l:
    if i == 1:
        l.remove(i)
print(l)
# Out:
# [1,4,6,2,1,2,1,5,1,54,1,6]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-134-d3d8fedbb9dc> in <cell line: 1>()
# ----> 1 l = list(map(int,input().split()))
#       2 for i in l:
#       3     if i == 1:
#       4         l.remove(i)
#       5 print(l)
#
# ValueError: invalid literal for int() with base 10: '[1,4,6,2,1,2,1,5,1,54,1,6]'

# %%
for i in givenList:
    if i == 1:
        givenList.remove(i)
print(givenList)
# Out:
# [4, 6, 2, 2, 5, 54, 6]

# %%
while givenList.count(1) !=0:
    givenList.remove(1)

# %%
givenList
# Out:
# [4, 6, 2, 2, 5, 54, 6]

# %%
while 1 in givenList:
    givenList.remove(1)

# %%
givenList
# Out:
# [4, 6, 2, 2, 5, 54, 6]

# %%
givenList
# Out:
# [4, 6, 2, 2, 5, 54, 6]

# %%
givenList.remove(2)

# %%
givenList
# Out:
# [4, 6, 5, 54, 6]

# %% [markdown]
# # pop

# %%
givenList
# Out:
# [4, 6, 5, 54, 6]

# %%
givenList[2]
# Out:
# 5

# %%
# Remove and return item at index (default last)
givenList.pop()
# Out:
# 6

# %%
givenList
# Out:
# [4, 6, 5, 54]

# %%
givenList.pop(0)
# Out:
# 4

# %%
givenList
# Out:
# [6, 5, 54]

# %%
givenList.pop()
givenList.pop()
givenList.pop()
# Out:
# 6

# %%
givenList
# Out:
# []

# %%
givenList.pop()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-153-9bf05b12518f> in <cell line: 1>()
# ----> 1 givenList.pop()
#
# IndexError: pop from empty list

# %%
givenList = [1,2,3,4,5,6]

# %%
while len(givenList)!=0:
    print(givenList.pop())
# Out:
# 6
# 5
# 4
# 3
# 2
# 1

# %%
givenList
# Out:
# []

# %%
givenList.pop()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[245], line 1
# ----> 1 givenList.pop()
#
# IndexError: pop from empty list

# %%
givenList = [1,2,3,4,5,6]

# %%
givenList.remove(1)

# %%
givenList
# Out:
# [2, 3, 4, 5, 6]

# %%
givenList.pop(1)
# Out:
# 3

# %%
givenList
# Out:
# [2, 4, 5, 6]

# %% [markdown]
# # remove work on value and pop on index

# %% [markdown]
# # Clear

# %%
givenList = [1,2,3,4,5,6]

# %%
givenList.clear()

# %%
givenList
# Out:
# []

# %%
del(givenList)

# %%
givenList
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-165-a46c7164fd5e> in <cell line: 1>()
# ----> 1 givenList
#
# NameError: name 'givenList' is not defined

# %% [markdown]
# # delete the bag itself , clear empties the bag

# %% [markdown]
# # reverse

# %%
givenList = [1,20,34,42,555,62]

# %%
givenList.reverse()

# %%
givenList
# Out:
# [62, 555, 42, 34, 20, 1]

# %%
givenList[::-1] # Equivalent to reverse
# Out:
# [1, 20, 34, 42, 555, 62]

# %% [markdown]
# # sort

# %%
givenList
# Out:
# [62, 555, 42, 34, 20, 1]

# %%
givenList.sort()

# %%
givenList
# Out:
# [1, 20, 34, 42, 62, 555]

# %%
givenList = [1,20,34,42,555,62]

# %%
givenList
# Out:
# [1, 20, 34, 42, 555, 62]

# %% [markdown]
# # Copy

# %%
givenList = [1,20,34,42,555,62]

# %%
newGivenList = givenList.copy()

# %%
newGivenList
# Out:
# [1, 20, 34, 42, 555, 62]

# %%
id(givenList)
# Out:
# 134090565879296

# %%
id(newGivenList)
# Out:
# 134090565941504

# %% [markdown]
# # Shallow Copy

# %%
givenList = [1,20,34,42,555,62]

# %%
shallowGivenList = givenList

# %%
shallowGivenList
# Out:
# [1, 20, 34, 42, 555, 62]

# %%
shallowGivenList.pop()
# Out:
# 62

# %%
givenList
# Out:
# [1, 20, 34, 42, 555]

# %%
id(givenList)
# Out:
# 134090565935552

# %%
id(shallowGivenList)
# Out:
# 134090565935552

# %%
# Homework : Deep Copy vs Shallow Copy

# %%
l1 = [1,2,4,6,2,1,5,2,1]

# %%
l1.index(1)
# Out:
# 0

# %%
l1.index(1,8)
# Out:
# 8

# %%
sorted
