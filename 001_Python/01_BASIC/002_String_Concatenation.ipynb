# %% [markdown]
# # String Concatenation

# %%
print ( "Hello" + "World")
# Out:
# HelloWorld

# %% [markdown]
# # + is acting like a concatenator

# %%
"string" + "string 2 " + " " + "1"
# Out:
# 'stringstring 2  1'

# %%
print ( "Good" + "Night")
# Out:
# GoodNight

# %%
print( "yes" * 3)
# Out:
# yesyesyes

# %% [markdown]
# # * acts like a multiplier which copies your strings

# %%
print( "yes" / 3)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-5-2d1b7bcaf32e> in <cell line: 1>()
# ----> 1 print( "yes" / 3)
#
# TypeError: unsupported operand type(s) for /: 'str' and 'int'

# %%
print( "yes" - 3)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-6-dc325d7e2b46> in <cell line: 1>()
# ----> 1 print( "yes" - 3)
#
# TypeError: unsupported operand type(s) for -: 'str' and 'int'

# %%
url = "www."
com = ".com"

# %%
website = input("Enter website you wanna visit")
# Out:
# Enter website you wanna visitgoogle

# %%
print(url + website+com)
# Out:
# www.google.com
