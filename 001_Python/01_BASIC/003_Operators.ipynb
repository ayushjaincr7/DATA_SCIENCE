# %% [markdown]
# # Slicing In Python Strings

# %%
p = "PYTHON"

# %%
p[5]
# Out:
# 'N'

# %%
p[-3]
# Out:
# 'H'

# %%
p[8]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-24-b24a4c5a0fa2> in <cell line: 1>()
# ----> 1 p[8]
#
# IndexError: string index out of range

# %%
p[-10]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-5-7a45fd75ce8e> in <cell line: 1>()
# ----> 1 p[-10]
#
# IndexError: string index out of range

# %%
p[0 : 3]
# Out:
# 'PYT'

# %%
p[1:3]
# Out:
# 'YT'

# %%
p[0:10]
# Out:
# 'PYTHON'

# %%
p[5:10000]
# Out:
# 'N'

# %%
c = "Bangalore"

# %%
c[4:len(c)]
# Out:
# 'alore'

# %%
c[4:8]
# Out:
# 'alor'

# %%
c[4:-3]
# Out:
# 'al'

# %%
str[2:2]
# Out:
# ''

# %%
p= "PYTHON"
str[6:10]
# Out:
# ''

# %%
p[:]
# Out:
# 'PYTHON'

# %%
p[]
# Out:
#   File "<ipython-input-40-5a469633179f>", line 1
#     p[]
#       ^
# SyntaxError: invalid syntax

# %%
p[-4:-1]
# Out:
# 'THO'

# %%
p[-1:-4]
# Out:
# ''

# %%
p[5:2]
# Out:
# ''

# %%
p[2:2]
# Out:
# ''

# %%
p
# Out:
# 'PYTHON'

# %%
p[-2:-5:-2]
# Out:
# 'OT'

# %%
p[-2:-5:2]
# Out:
# ''

# %%
p[0:6:2]
# Out:
# 'PTO'

# %%
p[1:8:2]
# Out:
# 'YHN'

# %%
p
# Out:
# 'PYTHON'

# %%
p[1:100:10000]
# Out:
# 'Y'

# %%
list(range(0,6,2))
# Out:
# [0, 2, 4]

# %%
p[5:2:-1]
# Out:
# 'NOH'

# %%
p[::-1]
# Out:
# 'NOHTYP'

# %%
p[::]
# Out:
# 'PYTHON'

# %%
p[::-1]
# Out:
# 'NOHTYP'

# %%
p[5:2:-2]
# Out:
# 'NH'

# %%
p[-2:-5:-1]
# Out:
# 'OHT'

# %% [markdown]
# # Operators
#
# # Modulus %

# %%
6 % 10
# Out:
# 6

# %%
500 % 100
# Out:
# 0

# %%
500 % 1000
# Out:
# 500

# %% [markdown]
# # Exponentiation

# %%
2 ** 2
# Out:
# 4

# %%
3 ** 500
# Out:
# 36360291795869936842385267079543319118023385026001623040346035832580600191583895484198508262979388783308179702534403855752855931517013066142992430916562025780021771247847643450125342836565813209972590371590152578728008385990139795377610001

# %%
3 ** 0
# Out:
# 1

# %%
x = 4
y = 8

# %%
print(x + y)
print(x - y)
print(x * y)
print(x/y)
# Out:
# 12
# -4
# 32
# 0.5

# %% [markdown]
# # Floor Division

# %%
3 // 2
# Out:
# 1

# %%
8//3
# Out:
# 2

# %%
8/3
# Out:
# 2.6666666666666665

# %%
5 // 10
# Out:
# 0

# %%
29 //10
# Out:
# 2

# %%
8//3
# Out:
# 2

# %%
8/3
# Out:
# 2.6666666666666665

# %%
6 > 8
# Out:
# False

# %%
8 >6
# Out:
# True

# %%
8==8
# Out:
# True

# %%
8!=10
# Out:
# True

# %%
"hi" == "hi"
# Out:
# True

# %%
"abc" > "yz"
# Out:
# False

# %%
ord('A')
# Out:
# 65

# %%
ord("abc")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-14-97301f0da54e> in <cell line: 1>()
# ----> 1 ord("abc")
#
# TypeError: ord() expected a character, but string of length 3 found

# %%
ord('m')
# Out:
# 109

# %%
"BLR" == "blr"
# Out:
# False

# %%
ord('x')
# Out:
# 120

# %%
ord('a')
# Out:
# 97

# %%
ord('b')
# Out:
# 98

# %%
ord('c')
# Out:
# 99

# %%
"ab" > "ac"
# Out:
# False

# %%
'A' > 'a'
# Out:
# False

# %%
'foo' > 'food'
# Out:
# False

# %%
'abc' > 'acb'
# Out:
# False

# %%
'abc' < 'acb'
# Out:
# True

# %%
ord('A')
# Out:
# 65

# %%
ord('a')
# Out:
# 97

# %%
'A'<  'a'
# Out:
# True

# %%
'ayaaaa' < 'az'
# Out:
# True

# %%
'ab' < 'cd'
# Out:
# True

# %%
ord('$')
# Out:
# 36

# %%
'$aaaaaa'  < 'A'
# Out:
# True

# %%
'ayaaa' < 'az'
# Out:
# True

# %%
1 < 3 < 5
# Out:
# True

# %%
5 < 6 > 7
# Out:
# False

# %%
1 == '1'
# Out:
# False

# %%
97 == 'a'
# Out:
# False

# %%
97 !='a'
# Out:
# True

# %%
97 == ord('a')
# Out:
# True

# %%
inp = input("enter a number")
# Out:
# enter a number 1

# %%
type(inp)
# Out:
# str

# %%
type(1)
# Out:
# int

# %%
1 == inp
# Out:
# False

# %%
'1' == inp
# Out:
# True

# %%
True and True
# Out:
# True

# %%
a = 20
b = 30
c= 50
b > a and b>c
# Out:
# False

# %%
'a' > 'a'  and True
# Out:
# False

# %%
'Sachin' and 10
# Out:
# 10

# %%
0 and 'hello'
# Out:
# 0

# %%
0 or 'hello'
# Out:
# 'hello'

# %%
not 0
# Out:
# True

# %%
'Bombay' and 'Mumbai'
# Out:
# 'Mumbai'

# %%
'Mayank' or 10
# Out:
# 'Mayank'

# %%
0 and True
# Out:
# 0

# %%
not 0
# Out:
# True

# %%
type(1)
# Out:
# int

# %%
type(True)
# Out:
# bool

# %%
1 == True
# Out:
# True

# %%
True + True
# Out:
# 2
