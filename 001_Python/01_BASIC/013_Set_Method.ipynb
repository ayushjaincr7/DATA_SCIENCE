# %% [markdown]
#  # set Methods

# %% [markdown]
# 1. add()
# 2. clear()
# 3. copy()
# 4. pop()
# 5. remove()
# 6. difference()
# 7. Update()

# %%
s1 = {1,2,3}

# %% [markdown]
# # add

# %%
s1.add(4)

# %%
s1
# Out:
# {1, 2, 3, 4}

# %% [markdown]
# # copy()

# %%
s2 = s1.copy()

# %%
s2
# Out:
# {1, 2, 3, 4}

# %%
s1
# Out:
# {1, 2, 3, 4}

# %%
s1.add(5)

# %%
s1
# Out:
# {1, 2, 3, 4, 5}

# %%
s2
# Out:
# {1, 2, 3, 4}

# %%
s2.add(6)

# %%
s2
# Out:
# {1, 2, 3, 4, 6}

# %%
s1
# Out:
# {1, 2, 3, 4, 5}

# %%
for i in s1:
    print(id(i))
# Out:
# 138452268187888
# 138452268187920
# 138452268187952
# 138452268187984
# 138452268188016

# %%
for j in s2:
    print(id(j))
# Out:
# 138452268187888
# 138452268187920
# 138452268187952
# 138452268187984
# 138452268188048

# %%
id(s1)
# Out:
# 138451974910496

# %%
id(s2)
# Out:
# 138451974908480

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[19], line 2
#       1 l1 = list((1,2,3))
# ----> 2 s3 = {l1}
#
# TypeError: unhashable type: 'list'

# %% [markdown]
# # clear()

# %%
s1.clear()

# %%
s1
# Out:
# set()

# %%
# del(s1)

# %% [markdown]
# # pop()

# %%
s1 = {1,2,3}

# %%
'''
Docstring:
Remove and return an arbitrary set element.
Raises KeyError if the set is empty.

Set don't have a sequence
'''

s1.pop()
# Out:
# 1

# %%
while (len(s1) !=0):
    ele = s1.pop()
    print(ele)
# Out:
# 2
# 3

# %%
len(s1)
# Out:
# 0

# %% [markdown]
# # remove

# %%
s1
# Out:
# set()

# %%
s1.remove(12)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-24-492049840ed8> in <cell line: 1>()
# ----> 1 s1.remove(12)
#
# KeyError: 12

# %%
s1.remove(3)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-26-8f6b13d8cdb1> in <cell line: 1>()
# ----> 1 s1.remove(3)
#
# KeyError: 3

# %%
s1
# Out:
# set()

# %% [markdown]
# # difference

# %%
s1 = {1,2,3}

# %%
s2 = {2,3,4}

# %%
'''
Return the difference of two or more sets as a new set.

(i.e. all elements that are in this set but not the others.)
'''


s1.difference(s2)
# Out:
# {1}

# %%
s1
# Out:
# {1, 2, 3}

# %%
'''
Remove all elements of another set from this set
'''

s1.difference_update(s2)

# %%
s1
# Out:
# {1}

# %%
s3 = {8,9,10}

# %%
s4 = {11,12,8,9}

# %%
s3.update(s4) #s3 is updated with union

# %%
s3
# Out:
# {8, 9, 10, 11, 12}

# %%
s5 =  s3.union(s4) # just returning
# s3 is not updated

# %%
s5
# Out:
# {8, 9, 10, 11, 12}

# %%
s3
# Out:
# {8, 9, 10, 11, 12}

# %%
s5
# Out:
# {8, 9, 10, 11, 12}

# %%
s1 = {1,2,3}
s2 = {2,3,4}

# %%
s3 = s1 + s2
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-45-25608ac9412d> in <cell line: 1>()
# ----> 1 s3 = s1 + s2
#
# TypeError: unsupported operand type(s) for +: 'set' and 'set'

# %%
s4 = s1-s2

# %%
s4
# Out:
# {1}

# %% [markdown]
# # I don’t understand clearly,  how  it loops over set elements as set don’t have an order ? Internally how does it work ?#
